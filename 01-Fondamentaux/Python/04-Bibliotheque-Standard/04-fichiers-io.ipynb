# %% [markdown]
# # ⚡ Intermédiaire | ⏱ 45 min | 🔑 Concepts : open, read, write, CSV, JSON, with
#
# # Lecture et Écriture de Fichiers (I/O)
#
# ## 🎯 Objectifs
#
# - Maîtriser `open()` et ses différents modes
# - Comprendre l'importance du context manager `with`
# - Manipuler les fichiers CSV avec le module `csv`
# - Gérer les données JSON avec le module `json`
# - Traiter efficacement de gros fichiers ligne par ligne
# - Gérer l'encodage des caractères
# - Utiliser les fichiers temporaires
#
# ## 📋 Prérequis
#
# - Python 3.8+
# - Connaissances de base en manipulation de chaînes
# - Compréhension des concepts de fichiers

# %% [markdown]
# ## 1. open() : Les modes d'ouverture
#
# La fonction `open()` est la base de l'I/O en Python.
#
# ### Modes d'ouverture
#
# | Mode | Description | Crée | Tronque | Position |
# |------|-------------|------|---------|----------|
# | `r` | Lecture (défaut) | ❌ | ❌ | Début |
# | `w` | Écriture | ✅ | ✅ | Début |
# | `a` | Ajout | ✅ | ❌ | Fin |
# | `x` | Création exclusive | ✅ | - | Début |
# | `r+` | Lecture + Écriture | ❌ | ❌ | Début |
# | `w+` | Lecture + Écriture | ✅ | ✅ | Début |
# | `a+` | Lecture + Ajout | ✅ | ❌ | Fin |
#
# ### Modificateurs
#
# - `b` : Mode binaire (ex: `rb`, `wb`)
# - `t` : Mode texte (défaut, ex: `rt`, `wt`)
# - `+` : Ouvrir pour mise à jour (lecture et écriture)

# %%
from pathlib import Path
import tempfile

# Créer un répertoire temporaire pour les tests
temp_dir = Path(tempfile.mkdtemp(prefix='io_demo_'))
print(f"Répertoire de test : {temp_dir}\n")

# Mode 'w' : écriture (écrase le fichier s'il existe)
fichier_w = temp_dir / 'ecriture.txt'
with open(fichier_w, 'w') as f:
    f.write('Première ligne\n')
    f.write('Deuxième ligne\n')

print("Mode 'w' (écriture) :")
print(f"  ✅ Fichier créé : {fichier_w.name}")
print(f"  Contenu : {fichier_w.read_text()!r}")

# Mode 'a' : ajout (ajoute à la fin)
with open(fichier_w, 'a') as f:
    f.write('Troisième ligne (ajoutée)\n')

print("\nMode 'a' (ajout) :")
print(f"  Contenu : {fichier_w.read_text()!r}")

# Mode 'r' : lecture
with open(fichier_w, 'r') as f:
    contenu = f.read()

print("\nMode 'r' (lecture) :")
print(f"  Contenu lu :\n{contenu}")

# Mode 'x' : création exclusive (erreur si existe)
fichier_x = temp_dir / 'nouveau.txt'
try:
    with open(fichier_x, 'x') as f:
        f.write('Fichier créé en mode exclusif')
    print("Mode 'x' (création exclusive) :")
    print(f"  ✅ Fichier créé : {fichier_x.name}")
except FileExistsError:
    print(f"  ❌ Le fichier existe déjà")

# Tenter de recréer (erreur)
try:
    with open(fichier_x, 'x') as f:
        f.write('Ceci échouera')
except FileExistsError:
    print(f"  ❌ Erreur attendue : le fichier existe déjà")

# %% [markdown]
# ## 2. Méthodes de lecture
#
# - `read()` : Lit tout le fichier en une chaîne
# - `read(n)` : Lit n caractères
# - `readline()` : Lit une ligne
# - `readlines()` : Lit toutes les lignes dans une liste
# - Itération : `for line in file:` (recommandé pour gros fichiers)

# %%
from pathlib import Path

# Créer un fichier de test
fichier_test = temp_dir / 'lecture.txt'
fichier_test.write_text("""Ligne 1: Introduction
Ligne 2: Développement
Ligne 3: Conclusion
Ligne 4: Fin""")

# read() : tout lire
print("1. read() - Lire tout le fichier :")
with open(fichier_test, 'r') as f:
    contenu = f.read()
print(f"  Type : {type(contenu)}")
print(f"  Longueur : {len(contenu)} caractères")
print(f"  Contenu :\n{contenu}\n")

# read(n) : lire n caractères
print("2. read(20) - Lire 20 caractères :")
with open(fichier_test, 'r') as f:
    debut = f.read(20)
    suite = f.read(20)
print(f"  Premiers 20 : {debut!r}")
print(f"  Suivants 20 : {suite!r}\n")

# readline() : lire ligne par ligne
print("3. readline() - Lire ligne par ligne :")
with open(fichier_test, 'r') as f:
    ligne1 = f.readline()
    ligne2 = f.readline()
print(f"  Ligne 1 : {ligne1!r}")
print(f"  Ligne 2 : {ligne2!r}\n")

# readlines() : toutes les lignes
print("4. readlines() - Toutes les lignes :")
with open(fichier_test, 'r') as f:
    lignes = f.readlines()
print(f"  Type : {type(lignes)}")
print(f"  Nombre de lignes : {len(lignes)}")
for i, ligne in enumerate(lignes, 1):
    print(f"  {i}: {ligne.rstrip()}")

# Itération (RECOMMANDÉ pour gros fichiers)
print("\n5. Itération - for line in file (efficace) :")
with open(fichier_test, 'r') as f:
    for i, ligne in enumerate(f, 1):
        print(f"  {i}: {ligne.rstrip()}")

# %% [markdown]
# ## 3. Méthodes d'écriture
#
# - `write(s)` : Écrit une chaîne (retourne le nombre de caractères écrits)
# - `writelines(lines)` : Écrit une séquence de chaînes (sans ajouter `\n`)

# %%
# write() : écrire une chaîne
print("1. write() - Écrire des chaînes :")
fichier_ecriture = temp_dir / 'ecriture_test.txt'
with open(fichier_ecriture, 'w') as f:
    n1 = f.write('Première ligne\n')
    n2 = f.write('Deuxième ligne\n')
    print(f"  Caractères écrits : {n1}, {n2}")

print(f"  Contenu : {fichier_ecriture.read_text()!r}\n")

# writelines() : écrire plusieurs lignes
print("2. writelines() - Écrire une liste :")
lignes = ['Ligne A\n', 'Ligne B\n', 'Ligne C\n']
with open(fichier_ecriture, 'w') as f:
    f.writelines(lignes)

print(f"  Contenu : {fichier_ecriture.read_text()!r}\n")

# ⚠️ writelines() n'ajoute PAS de \n automatiquement
print("3. ⚠️ writelines() sans \\n :")
lignes_sans_n = ['Ligne 1', 'Ligne 2', 'Ligne 3']
with open(fichier_ecriture, 'w') as f:
    f.writelines(lignes_sans_n)

print(f"  Contenu : {fichier_ecriture.read_text()!r}")
print("  → Tout sur une ligne !\n")

# Solution : ajouter \n manuellement
print("4. ✅ Solution : ajouter \\n :")
with open(fichier_ecriture, 'w') as f:
    f.writelines(ligne + '\n' for ligne in lignes_sans_n)

print(f"  Contenu :\n{fichier_ecriture.read_text()}")

# %% [markdown]
# ## 4. Context Manager : with statement
#
# **TOUJOURS utiliser `with` pour ouvrir des fichiers !**
#
# Avantages :
# - ✅ Fermeture automatique du fichier (même en cas d'erreur)
# - ✅ Gestion propre des ressources
# - ✅ Code plus lisible
# - ✅ Évite les fuites de ressources

# %%
# ❌ MAUVAIS : sans with (risque de fuite)
print("❌ Sans with (à éviter) :\n")
fichier_bad = temp_dir / 'bad.txt'
f = open(fichier_bad, 'w')
f.write('Contenu')
f.close()  # Si erreur avant, le fichier reste ouvert !
print("  Problème : si erreur avant close(), fuite de ressource\n")

# ❌ TRÈS MAUVAIS : oublier close()
print("❌ Sans close() (très mauvais) :\n")
f = open(fichier_bad, 'w')
f.write('Contenu')
# Oups, pas de close() !
print("  Problème : fichier reste ouvert → fuite de ressource\n")

# ✅ BON : avec with
print("✅ Avec with (recommandé) :\n")
fichier_good = temp_dir / 'good.txt'
with open(fichier_good, 'w') as f:
    f.write('Contenu')
    # f.close() appelé automatiquement à la sortie du bloc

print("  ✅ Fichier fermé automatiquement")
print(f"  Fichier fermé ? {f.closed}\n")

# ✅ Gestion d'erreur avec with
print("✅ Avec with + gestion d'erreur :\n")
try:
    with open(fichier_good, 'w') as f:
        f.write('Début\n')
        raise ValueError("Erreur simulée")
        f.write('Fin\n')  # Ne sera jamais exécuté
except ValueError as e:
    print(f"  ⚠️ Erreur capturée : {e}")
    print(f"  ✅ Fichier fermé malgré l'erreur : {f.closed}")

print(f"\n  Contenu écrit avant l'erreur : {fichier_good.read_text()!r}")

# %% [markdown]
# ### 4.1 Ouvrir plusieurs fichiers avec with

# %%
# Méthode 1 : Nested with
print("Méthode 1 : Nested with\n")
source = temp_dir / 'source.txt'
dest = temp_dir / 'destination.txt'
source.write_text('Contenu à copier')

with open(source, 'r') as f_in:
    with open(dest, 'w') as f_out:
        contenu = f_in.read()
        f_out.write(contenu)

print(f"  ✅ Copié : {dest.read_text()}\n")

# Méthode 2 : with multiple (Python 3.1+)
print("Méthode 2 : with multiple (recommandé)\n")
with open(source, 'r') as f_in, open(dest, 'w') as f_out:
    contenu = f_in.read()
    f_out.write(contenu.upper())  # En majuscules

print(f"  ✅ Copié en majuscules : {dest.read_text()}")

# %% [markdown]
# ## 5. Encodage : encoding='utf-8'
#
# **Toujours spécifier l'encodage explicitement !**
#
# Par défaut, Python utilise l'encodage du système (peut varier).
# - Windows : souvent `cp1252` ou `latin-1`
# - Linux/Mac : souvent `utf-8`
#
# **Best practice** : Toujours utiliser `encoding='utf-8'`

# %%
import locale

# Encodage par défaut du système
print("Encodage par défaut :")
print(f"  Système : {locale.getpreferredencoding()}")
print(f"  Python : {locale.getdefaultlocale()}\n")

# Texte avec caractères spéciaux
texte_unicode = """Français : éèêëàâäôöùûü
Espagnol : ñáéíóú
Allemand : äöüß
Japonais : 日本語
Émojis : 🐍 🚀 💻"""

fichier_utf8 = temp_dir / 'utf8.txt'

# ✅ BON : avec encoding='utf-8'
print("✅ Écriture avec encoding='utf-8' :\n")
with open(fichier_utf8, 'w', encoding='utf-8') as f:
    f.write(texte_unicode)

# Lecture avec utf-8
with open(fichier_utf8, 'r', encoding='utf-8') as f:
    contenu = f.read()

print(f"Contenu lu :\n{contenu}\n")

# ❌ Problème : lire avec mauvais encodage
print("❌ Lecture avec mauvais encodage (latin-1) :\n")
try:
    with open(fichier_utf8, 'r', encoding='latin-1') as f:
        contenu_mauvais = f.read()
    print(f"  Résultat corrompu :\n{contenu_mauvais[:100]}...")
except Exception as e:
    print(f"  Erreur : {e}")

print("\n→ Toujours utiliser encoding='utf-8' pour la portabilité !")

# %% [markdown]
# ## 6. Module csv : Lire et écrire des CSV
#
# Le module `csv` gère automatiquement :
# - Les guillemets
# - Les virgules dans les valeurs
# - Les sauts de ligne
# - Les différents délimiteurs

# %%
import csv

# Écrire un CSV avec csv.writer
print("1. csv.writer - Écriture basique :\n")
fichier_csv = temp_dir / 'data.csv'

with open(fichier_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Nom', 'Age', 'Ville'])
    writer.writerow(['Alice', 30, 'Paris'])
    writer.writerow(['Bob', 25, 'Lyon'])
    writer.writerow(['Charlie', 35, 'Marseille'])

print(f"  ✅ CSV créé\n  Contenu :\n{fichier_csv.read_text()}")

# Lire un CSV avec csv.reader
print("2. csv.reader - Lecture basique :\n")
with open(fichier_csv, 'r', newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    for i, row in enumerate(reader, 1):
        print(f"  Ligne {i}: {row}")

# %% [markdown]
# ### 6.1 DictReader et DictWriter (recommandé)

# %%
import csv

# DictWriter : écrire avec des dictionnaires
print("1. DictWriter - Écriture avec dictionnaires :\n")
fichier_dict_csv = temp_dir / 'personnes.csv'

personnes = [
    {'nom': 'Alice', 'age': 30, 'ville': 'Paris', 'profession': 'Ingénieur'},
    {'nom': 'Bob', 'age': 25, 'ville': 'Lyon', 'profession': 'Designer'},
    {'nom': 'Charlie', 'age': 35, 'ville': 'Marseille', 'profession': 'Manager'},
]

fieldnames = ['nom', 'age', 'ville', 'profession']

with open(fichier_dict_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()  # Écrire l'en-tête
    writer.writerows(personnes)

print(f"  ✅ CSV créé\n  Contenu :\n{fichier_dict_csv.read_text()}")

# DictReader : lire avec des dictionnaires
print("\n2. DictReader - Lecture avec dictionnaires :\n")
with open(fichier_dict_csv, 'r', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for i, row in enumerate(reader, 1):
        print(f"  Personne {i}:")
        for key, value in row.items():
            print(f"    {key:12} : {value}")
        print()

# %% [markdown]
# ### 6.2 Options avancées CSV

# %%
import csv

# Différents délimiteurs
print("1. CSV avec délimiteur personnalisé (;) :\n")
fichier_semicolon = temp_dir / 'data_semicolon.csv'

with open(fichier_semicolon, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=';')
    writer.writerow(['Produit', 'Prix', 'Quantité'])
    writer.writerow(['Pomme', '2.50', '10'])
    writer.writerow(['Orange', '3.00', '5'])

print(f"  Contenu :\n{fichier_semicolon.read_text()}")

# Guillemets et échappement
print("2. Gestion des guillemets et virgules :\n")
fichier_quotes = temp_dir / 'data_quotes.csv'

with open(fichier_quotes, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['Nom', 'Description'])
    writer.writerow(['Produit A', 'Ceci contient, une virgule'])
    writer.writerow(['Produit B', 'Ceci contient "des guillemets"'])
    writer.writerow(['Produit C', 'Texte\nsur\nplusieurs\nlignes'])

print(f"  Contenu :\n{fichier_quotes.read_text()}")
print("  → Les valeurs avec virgules/guillemets sont automatiquement échappées\n")

# Lire avec le bon délimiteur
print("3. Lecture avec délimiteur ; :\n")
with open(fichier_semicolon, 'r', newline='', encoding='utf-8') as f:
    reader = csv.reader(f, delimiter=';')
    for row in reader:
        print(f"  {row}")

# %% [markdown]
# ## 7. Module json : Gérer les données JSON
#
# Le module `json` permet de sérialiser/désérialiser des données Python en JSON.
#
# Fonctions principales :
# - `json.dump(obj, file)` : Écrire dans un fichier
# - `json.dumps(obj)` : Convertir en chaîne
# - `json.load(file)` : Lire depuis un fichier
# - `json.loads(string)` : Convertir depuis une chaîne

# %%
import json

# Données Python
data = {
    'nom': 'Mon Application',
    'version': '1.0.0',
    'auteur': {
        'nom': 'Alice',
        'email': 'alice@example.com'
    },
    'features': ['feature1', 'feature2', 'feature3'],
    'actif': True,
    'utilisateurs': 1234,
    'coefficient': 3.14
}

# 1. dumps() : convertir en chaîne JSON
print("1. json.dumps() - Convertir en chaîne :\n")
json_string = json.dumps(data)
print(f"  Compact : {json_string[:80]}...\n")

# Avec indentation (lisible)
json_pretty = json.dumps(data, indent=2, ensure_ascii=False)
print(f"  Formaté :\n{json_pretty}\n")

# 2. dump() : écrire dans un fichier
print("2. json.dump() - Écrire dans un fichier :\n")
fichier_json = temp_dir / 'config.json'

with open(fichier_json, 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

print(f"  ✅ Fichier créé\n  Contenu :\n{fichier_json.read_text()}")

# %%
import json

# 3. load() : lire depuis un fichier
print("3. json.load() - Lire depuis un fichier :\n")
with open(fichier_json, 'r', encoding='utf-8') as f:
    data_loaded = json.load(f)

print(f"  Type : {type(data_loaded)}")
print(f"  Nom : {data_loaded['nom']}")
print(f"  Version : {data_loaded['version']}")
print(f"  Features : {data_loaded['features']}\n")

# 4. loads() : convertir depuis une chaîne
print("4. json.loads() - Convertir depuis une chaîne :\n")
json_str = '{"name": "Python", "version": 3.11, "active": true}'
data_from_str = json.loads(json_str)
print(f"  Chaîne JSON : {json_str}")
print(f"  Converti : {data_from_str}")
print(f"  Type : {type(data_from_str)}")

# %% [markdown]
# ### 7.1 Options JSON avancées

# %%
import json
from datetime import datetime

# Tri des clés
print("1. Tri des clés (sort_keys=True) :\n")
data_unsorted = {'z': 1, 'a': 2, 'm': 3}
print(f"  Sans tri : {json.dumps(data_unsorted)}")
print(f"  Avec tri : {json.dumps(data_unsorted, sort_keys=True)}\n")

# Sérialisation personnalisée
print("2. Sérialisation personnalisée :\n")

class CustomEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, datetime):
            return obj.isoformat()
        return super().default(obj)

data_with_date = {
    'timestamp': datetime.now(),
    'message': 'Hello'
}

# Avec l'encoder personnalisé
json_with_date = json.dumps(data_with_date, cls=CustomEncoder, indent=2)
print(f"  JSON avec date :\n{json_with_date}\n")

# ensure_ascii=False pour caractères non-ASCII
print("3. Caractères Unicode :\n")
data_unicode = {'message': 'Bonjour 🐍', 'auteur': 'François'}
print(f"  ensure_ascii=True  : {json.dumps(data_unicode, ensure_ascii=True)}")
print(f"  ensure_ascii=False : {json.dumps(data_unicode, ensure_ascii=False)}")

# %% [markdown]
# ## 8. Traitement ligne par ligne (gros fichiers)
#
# Pour traiter de gros fichiers, **NE PAS** charger tout en mémoire avec `read()` ou `readlines()`.
#
# **Utilisez l'itération** : `for line in file:`

# %%
# Créer un gros fichier de test
gros_fichier = temp_dir / 'gros_fichier.txt'
print("Création d'un fichier de test...\n")

# Écrire 10000 lignes
with open(gros_fichier, 'w', encoding='utf-8') as f:
    for i in range(10000):
        f.write(f"Ligne {i+1}: Données de test\n")

taille = gros_fichier.stat().st_size
print(f"✅ Fichier créé : {taille:,} octets\n")

# ❌ MAUVAIS : lire tout en mémoire
print("❌ Approche inefficace (tout en mémoire) :\n")
import sys

with open(gros_fichier, 'r', encoding='utf-8') as f:
    contenu = f.read()  # Charge TOUT en mémoire !
    lignes = contenu.split('\n')
    print(f"  Mémoire utilisée : ~{sys.getsizeof(contenu):,} octets")
    print(f"  Nombre de lignes : {len(lignes)}\n")

# ✅ BON : itération ligne par ligne
print("✅ Approche efficace (itération) :\n")
count = 0
with open(gros_fichier, 'r', encoding='utf-8') as f:
    for ligne in f:
        count += 1
        # Traiter chaque ligne individuellement
        # (seulement UNE ligne en mémoire à la fois)

print(f"  Lignes traitées : {count}")
print("  Mémoire : uniquement 1 ligne à la fois !\n")

# Exemple pratique : compter les mots
print("Exemple : compter les mots\n")
total_mots = 0
with open(gros_fichier, 'r', encoding='utf-8') as f:
    for ligne in f:
        total_mots += len(ligne.split())

print(f"  Total de mots : {total_mots:,}")

# %% [markdown]
# ## 9. Fichiers temporaires : tempfile
#
# Le module `tempfile` permet de créer des fichiers/dossiers temporaires de manière sécurisée.

# %%
import tempfile
import os

# NamedTemporaryFile : fichier temporaire avec nom
print("1. NamedTemporaryFile :\n")
with tempfile.NamedTemporaryFile(mode='w+', delete=False, suffix='.txt') as f:
    print(f"  Fichier temporaire : {f.name}")
    f.write('Contenu temporaire\n')
    f.write('Ligne 2\n')
    
    # Revenir au début pour lire
    f.seek(0)
    contenu = f.read()
    print(f"  Contenu : {contenu!r}")
    
    temp_name = f.name

# Vérifier que le fichier existe encore (delete=False)
print(f"  Existe après fermeture ? {os.path.exists(temp_name)}\n")

# Nettoyer manuellement
os.unlink(temp_name)

# TemporaryDirectory : dossier temporaire
print("2. TemporaryDirectory :\n")
with tempfile.TemporaryDirectory() as temp_dir:
    print(f"  Dossier temporaire : {temp_dir}")
    
    # Créer des fichiers dedans
    from pathlib import Path
    temp_path = Path(temp_dir)
    (temp_path / 'file1.txt').write_text('Test 1')
    (temp_path / 'file2.txt').write_text('Test 2')
    
    print(f"  Fichiers créés :")
    for f in temp_path.iterdir():
        print(f"    - {f.name}")
    
    temp_dir_name = temp_dir

# Le dossier est automatiquement supprimé
print(f"\n  Existe après sortie du bloc ? {os.path.exists(temp_dir_name)}")

# mkstemp() : créer un fichier temporaire (bas niveau)
print("\n3. mkstemp() :\n")
fd, path = tempfile.mkstemp(suffix='.txt', prefix='test_')
print(f"  File descriptor : {fd}")
print(f"  Chemin : {path}")

# Écrire avec os.write
os.write(fd, b'Contenu binaire')
os.close(fd)

# Lire
with open(path, 'r') as f:
    print(f"  Contenu : {f.read()}")

# Nettoyer
os.unlink(path)
print(f"  ✅ Nettoyé")

# %% [markdown]
# ## 🚨 Pièges courants
#
# ### 1. Oublier with

# %%
# ❌ MAUVAIS : oublier with
fichier = temp_dir / 'test_with.txt'

# Sans with
f = open(fichier, 'w')
f.write('Test')
# Si erreur ici, le fichier reste ouvert !
f.close()

print("❌ Sans with : risque de fuite de ressource\n")

# ✅ BON : avec with
with open(fichier, 'w') as f:
    f.write('Test')
    # Fermé automatiquement

print("✅ Avec with : sécurisé")

# %% [markdown]
# ### 2. Mode 'w' écrase tout

# %%
fichier = temp_dir / 'test_mode.txt'
fichier.write_text('Contenu original important')

print(f"Contenu initial : {fichier.read_text()!r}\n")

# ❌ DANGER : mode 'w' écrase TOUT
with open(fichier, 'w') as f:
    f.write('Nouveau')

print(f"❌ Après mode 'w' : {fichier.read_text()!r}")
print("   → Contenu original PERDU !\n")

# ✅ Pour ajouter, utiliser 'a'
fichier.write_text('Contenu de base')
with open(fichier, 'a') as f:
    f.write('\nAjout')

print(f"✅ Avec mode 'a' : {fichier.read_text()!r}")
print("   → Contenu préservé")

# %% [markdown]
# ### 3. Oublier encoding

# %%
import locale

texte_special = "Caractères spéciaux : éàç 日本語"
fichier = temp_dir / 'test_encoding.txt'

# ❌ Sans encoding (dépend du système)
print(f"Encodage par défaut du système : {locale.getpreferredencoding()}\n")

# ✅ Toujours spécifier encoding='utf-8'
with open(fichier, 'w', encoding='utf-8') as f:
    f.write(texte_special)

print("✅ Écrit avec encoding='utf-8'")
print(f"   Contenu : {fichier.read_text(encoding='utf-8')}")

# %% [markdown]
# ### 4. newline avec CSV (Windows)

# %%
import csv

fichier = temp_dir / 'test_csv.csv'

# ❌ PROBLÈME : sans newline='' sur Windows
# Peut créer des lignes vides supplémentaires

# ✅ SOLUTION : toujours utiliser newline=''
with open(fichier, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['A', 'B', 'C'])
    writer.writerow(['1', '2', '3'])

print("✅ CSV écrit avec newline=''")
print(f"Contenu :\n{fichier.read_text()}")
print("\n→ Sur Windows, sans newline='', vous auriez des lignes vides !")

# %% [markdown]
# ## 💪 Mini-exercices
#
# ### Exercice 1 : Lire et transformer un CSV
#
# Lire un CSV de produits et créer un nouveau CSV avec les produits dont le prix > 10€.

# %%
import csv

def filtrer_produits_chers(fichier_entree: str, fichier_sortie: str, seuil: float = 10.0) -> int:
    """
    Filtre les produits dont le prix est supérieur au seuil.
    
    Returns:
        Nombre de produits filtrés
    """
    # TODO: implémenter
    pass

# Test
# Créer un CSV de test
# ...
# count = filtrer_produits_chers('produits.csv', 'produits_chers.csv')
# print(f"{count} produits filtrés")

# %% [markdown]
# ### Solution Exercice 1

# %%
import csv
from pathlib import Path

def filtrer_produits_chers(fichier_entree: str, fichier_sortie: str, seuil: float = 10.0) -> int:
    """
    Filtre les produits dont le prix est supérieur au seuil.
    
    Returns:
        Nombre de produits filtrés
    """
    count = 0
    
    with open(fichier_entree, 'r', newline='', encoding='utf-8') as f_in, \
         open(fichier_sortie, 'w', newline='', encoding='utf-8') as f_out:
        
        reader = csv.DictReader(f_in)
        writer = csv.DictWriter(f_out, fieldnames=reader.fieldnames)
        
        # Écrire l'en-tête
        writer.writeheader()
        
        # Filtrer et écrire
        for row in reader:
            prix = float(row['prix'])
            if prix > seuil:
                writer.writerow(row)
                count += 1
    
    return count

# Test
fichier_produits = temp_dir / 'produits.csv'
fichier_chers = temp_dir / 'produits_chers.csv'

# Créer un CSV de test
produits = [
    {'nom': 'Pomme', 'prix': '2.50', 'categorie': 'Fruits'},
    {'nom': 'Laptop', 'prix': '899.99', 'categorie': 'Électronique'},
    {'nom': 'Livre', 'prix': '15.00', 'categorie': 'Livres'},
    {'nom': 'Stylo', 'prix': '1.50', 'categorie': 'Fournitures'},
    {'nom': 'Clavier', 'prix': '49.99', 'categorie': 'Électronique'},
    {'nom': 'Orange', 'prix': '3.00', 'categorie': 'Fruits'},
]

with open(fichier_produits, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['nom', 'prix', 'categorie'])
    writer.writeheader()
    writer.writerows(produits)

print("CSV original :")
print(fichier_produits.read_text())

# Filtrer
count = filtrer_produits_chers(fichier_produits, fichier_chers, seuil=10.0)

print(f"\n✅ {count} produits > 10€ filtrés\n")
print("CSV filtré :")
print(fichier_chers.read_text())

# %% [markdown]
# ### Exercice 2 : Configuration JSON
#
# Créer un système de gestion de configuration avec JSON.

# %%
import json
from pathlib import Path
from typing import Any, Dict

class Config:
    """
    Gestionnaire de configuration JSON.
    """
    
    def __init__(self, fichier: str):
        self.fichier = Path(fichier)
        self.data = self._load()
    
    def _load(self) -> Dict[str, Any]:
        """Charge la configuration depuis le fichier."""
        # TODO: implémenter
        pass
    
    def get(self, key: str, default=None) -> Any:
        """Récupère une valeur."""
        # TODO: implémenter
        pass
    
    def set(self, key: str, value: Any) -> None:
        """Définit une valeur."""
        # TODO: implémenter
        pass
    
    def save(self) -> None:
        """Sauvegarde la configuration."""
        # TODO: implémenter
        pass

# Test
# config = Config('app_config.json')
# config.set('debug', True)
# config.set('port', 8000)
# config.save()

# %% [markdown]
# ### Solution Exercice 2

# %%
import json
from pathlib import Path
from typing import Any, Dict

class Config:
    """
    Gestionnaire de configuration JSON.
    """
    
    def __init__(self, fichier: str):
        self.fichier = Path(fichier)
        self.data = self._load()
    
    def _load(self) -> Dict[str, Any]:
        """Charge la configuration depuis le fichier."""
        if self.fichier.exists():
            with open(self.fichier, 'r', encoding='utf-8') as f:
                return json.load(f)
        return {}
    
    def get(self, key: str, default=None) -> Any:
        """Récupère une valeur (supporte notation pointée)."""
        keys = key.split('.')
        value = self.data
        
        for k in keys:
            if isinstance(value, dict) and k in value:
                value = value[k]
            else:
                return default
        
        return value
    
    def set(self, key: str, value: Any) -> None:
        """Définit une valeur (supporte notation pointée)."""
        keys = key.split('.')
        data = self.data
        
        for k in keys[:-1]:
            if k not in data:
                data[k] = {}
            data = data[k]
        
        data[keys[-1]] = value
    
    def save(self) -> None:
        """Sauvegarde la configuration."""
        with open(self.fichier, 'w', encoding='utf-8') as f:
            json.dump(self.data, f, indent=2, ensure_ascii=False)
    
    def __repr__(self) -> str:
        return f"Config({self.fichier}): {len(self.data)} clés"

# Test
fichier_config = temp_dir / 'app_config.json'

print("Test du gestionnaire de configuration :\n")

# Créer et configurer
config = Config(fichier_config)
config.set('app.name', 'Mon Application')
config.set('app.version', '1.0.0')
config.set('server.host', 'localhost')
config.set('server.port', 8000)
config.set('debug', True)
config.set('features', ['feature1', 'feature2'])
config.save()

print(f"✅ Configuration sauvegardée dans {fichier_config.name}\n")
print("Contenu du fichier :")
print(fichier_config.read_text())

# Recharger depuis le fichier
print("\nRechargement de la configuration :")
config2 = Config(fichier_config)
print(f"  app.name : {config2.get('app.name')}")
print(f"  server.port : {config2.get('server.port')}")
print(f"  debug : {config2.get('debug')}")
print(f"  inexistant : {config2.get('inexistant', 'valeur par défaut')}")

# Modifier et sauvegarder
print("\nModification :")
config2.set('server.port', 9000)
config2.set('app.version', '1.1.0')
config2.save()
print("  ✅ Port changé à 9000")
print("  ✅ Version mise à jour")

print("\nNouveau contenu :")
print(fichier_config.read_text())

# %% [markdown]
# ### Exercice 3 : Fusionner des fichiers
#
# Créer une fonction qui fusionne plusieurs fichiers texte en un seul.

# %%
from pathlib import Path
from typing import List

def fusionner_fichiers(fichiers_entree: List[str], fichier_sortie: str, separateur: str = "\n" + "="*50 + "\n") -> None:
    """
    Fusionne plusieurs fichiers en un seul.
    
    Args:
        fichiers_entree: Liste des fichiers à fusionner
        fichier_sortie: Fichier de destination
        separateur: Séparateur entre fichiers
    """
    # TODO: implémenter
    pass

# Test
# fusionner_fichiers(['file1.txt', 'file2.txt', 'file3.txt'], 'merged.txt')

# %% [markdown]
# ### Solution Exercice 3

# %%
from pathlib import Path
from typing import List

def fusionner_fichiers(
    fichiers_entree: List[str],
    fichier_sortie: str,
    separateur: str = "\n" + "="*50 + "\n",
    avec_entete: bool = True
) -> None:
    """
    Fusionne plusieurs fichiers en un seul.
    
    Args:
        fichiers_entree: Liste des fichiers à fusionner
        fichier_sortie: Fichier de destination
        separateur: Séparateur entre fichiers
        avec_entete: Ajouter le nom du fichier en en-tête
    """
    with open(fichier_sortie, 'w', encoding='utf-8') as f_out:
        for i, fichier_in in enumerate(fichiers_entree):
            # Ajouter un séparateur (sauf pour le premier)
            if i > 0:
                f_out.write(separateur)
            
            # Ajouter l'en-tête si demandé
            if avec_entete:
                f_out.write(f"### Fichier : {Path(fichier_in).name} ###\n\n")
            
            # Copier le contenu
            with open(fichier_in, 'r', encoding='utf-8') as f_in:
                for ligne in f_in:
                    f_out.write(ligne)

# Test
print("Test de fusion de fichiers :\n")

# Créer des fichiers de test
fichiers_test = []
for i in range(1, 4):
    fichier = temp_dir / f'partie{i}.txt'
    fichier.write_text(f"""Ceci est la partie {i}.
Elle contient du contenu intéressant.
Ligne 3 de la partie {i}.""")
    fichiers_test.append(str(fichier))
    print(f"✅ Créé : {fichier.name}")

# Fusionner
fichier_fusion = temp_dir / 'fusion.txt'
fusionner_fichiers(fichiers_test, str(fichier_fusion))

print(f"\n✅ Fichiers fusionnés dans : {fichier_fusion.name}\n")
print("Contenu fusionné :")
print("=" * 60)
print(fichier_fusion.read_text())
print("=" * 60)

# Statistiques
lignes_totales = len(fichier_fusion.read_text().split('\n'))
taille = fichier_fusion.stat().st_size
print(f"\nStatistiques :")
print(f"  Lignes : {lignes_totales}")
print(f"  Taille : {taille} octets")

# %% [markdown]
# ## 📚 Ressources complémentaires
#
# - [Documentation open()](https://docs.python.org/3/library/functions.html#open)
# - [Documentation csv](https://docs.python.org/3/library/csv.html)
# - [Documentation json](https://docs.python.org/3/library/json.html)
# - [Documentation tempfile](https://docs.python.org/3/library/tempfile.html)
# - [Real Python - Reading and Writing Files](https://realpython.com/read-write-files-python/)
# - [PEP 343 - The "with" Statement](https://www.python.org/dev/peps/pep-0343/)
#
# ## 💡 Conseils
#
# 1. **Toujours utiliser `with`** : Garantit la fermeture automatique des fichiers
# 2. **Spécifier l'encodage** : `encoding='utf-8'` par défaut
# 3. **Mode 'w' écrase** : Attention avec le mode write
# 4. **CSV : newline=''** : Évite les problèmes sur Windows
# 5. **Gros fichiers** : Itérer ligne par ligne au lieu de `read()`
# 6. **JSON : indent=2** : Pour la lisibilité
# 7. **Fichiers temporaires** : Utilisez `tempfile` plutôt que créer manuellement
