# %% [markdown]
# # 🟢 Boucles et Itérations en Python
#
# **Badge:** 🟢 Débutant | ⏱ 45 min | 🔑 **Concepts:** for, while, range, enumerate, zip
#
# ---
#
# ## 📋 Objectifs
#
# À la fin de ce notebook, vous serez capable de :
# - Utiliser les boucles `for` et `while` efficacement
# - Maîtriser `range()`, `enumerate()` et `zip()`
# - Contrôler le flux avec `break`, `continue` et `pass`
# - Comprendre la clause `else` sur les boucles
# - Itérer sur différentes structures de données
# - Éviter les pièges courants des itérations
#
# ## 🎯 Prérequis
#
# - Connaissance des types de base (listes, tuples, dictionnaires)
# - Compréhension des conditions (if/elif/else)

# %% [markdown]
# ## 1. Boucle for - Bases

# %% [markdown]
# ### 1.1 Itération sur une séquence

# %%
# Itération sur une liste
fruits = ['pomme', 'banane', 'orange', 'kiwi']

for fruit in fruits:
    print(f"J'aime les {fruit}s")

# %%
# Itération sur une chaîne de caractères
message = "Python"

for lettre in message:
    print(lettre, end=' ')
print()  # Retour à la ligne

# %%
# Itération sur un tuple
coordonnees = (10, 20, 30)

for valeur in coordonnees:
    print(f"Valeur: {valeur}")

# %% [markdown]
# ### 1.2 La fonction range()
#
# `range()` génère une séquence de nombres. C'est l'outil principal pour créer des boucles avec compteur.

# %%
# range(stop) : de 0 à stop-1
print("range(5) :")
for i in range(5):
    print(i, end=' ')
print()

# range(start, stop) : de start à stop-1
print("\nrange(2, 8) :")
for i in range(2, 8):
    print(i, end=' ')
print()

# range(start, stop, step) : de start à stop-1 avec un pas de step
print("\nrange(0, 10, 2) :")
for i in range(0, 10, 2):
    print(i, end=' ')
print()

# %%
# Compter à rebours
print("Compte à rebours :")
for i in range(10, 0, -1):
    print(i, end=' ')
print("🚀")

# Nombres négatifs
print("\nNombres négatifs :")
for i in range(-5, 5):
    print(i, end=' ')
print()

# %%
# range() retourne un objet range, pas une liste
r = range(5)
print(f"Type: {type(r)}")
print(f"Range: {r}")

# Pour obtenir une liste, utiliser list()
print(f"Liste: {list(r)}")

# Avantage : range() est économe en mémoire
# Il génère les valeurs à la demande au lieu de les stocker toutes

# %% [markdown]
# ### 1.3 enumerate() - Obtenir l'index et la valeur

# %%
# enumerate() retourne un tuple (index, valeur)
fruits = ['pomme', 'banane', 'orange', 'kiwi']

print("Avec enumerate() :")
for index, fruit in enumerate(fruits):
    print(f"{index}: {fruit}")

# %%
# Commencer l'index à une valeur spécifique
print("Index commençant à 1 :")
for index, fruit in enumerate(fruits, start=1):
    print(f"{index}. {fruit}")

# %%
# Comparaison : sans enumerate() (moins pythonique)
print("Sans enumerate() :")
for i in range(len(fruits)):
    print(f"{i}: {fruits[i]}")

# Avec enumerate() (pythonique)
print("\nAvec enumerate() :")
for i, fruit in enumerate(fruits):
    print(f"{i}: {fruit}")

# %% [markdown]
# ### 1.4 zip() - Itération parallèle

# %%
# zip() permet d'itérer sur plusieurs séquences en parallèle
noms = ['Alice', 'Bob', 'Charlie']
ages = [25, 30, 35]
villes = ['Paris', 'Lyon', 'Marseille']

print("Avec zip() :")
for nom, age, ville in zip(noms, ages, villes):
    print(f"{nom}, {age} ans, habite à {ville}")

# %%
# zip() s'arrête à la séquence la plus courte
liste1 = [1, 2, 3, 4, 5]
liste2 = ['a', 'b', 'c']

print("Séquences de longueurs différentes :")
for nombre, lettre in zip(liste1, liste2):
    print(f"{nombre} - {lettre}")

print("\nNote: zip s'arrête à la liste la plus courte (3 éléments)")

# %%
# Créer un dictionnaire avec zip()
cles = ['nom', 'age', 'ville']
valeurs = ['Alice', 25, 'Paris']

dictionnaire = dict(zip(cles, valeurs))
print("Dictionnaire créé avec zip() :")
print(dictionnaire)

# %%
# Transposer une matrice avec zip()
matrice = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print("Matrice originale :")
for ligne in matrice:
    print(ligne)

transposee = list(zip(*matrice))
print("\nMatrice transposée :")
for ligne in transposee:
    print(ligne)

# %% [markdown]
# ## 2. Boucle while

# %% [markdown]
# ### 2.1 Syntaxe de base

# %%
# Boucle while simple
compteur = 0

print("Compteur de 0 à 4 :")
while compteur < 5:
    print(compteur, end=' ')
    compteur += 1
print()

# %%
# Exemple : saisie utilisateur avec validation
# Note: utilisez input() dans un environnement interactif
# Ici, simulation avec une valeur prédéfinie

def saisir_nombre():
    """
    Simule la saisie d'un nombre valide.
    """
    tentatives = ['abc', '12.5', '-10', '42']  # Simulation
    index = 0
    
    while index < len(tentatives):
        reponse = tentatives[index]
        print(f"Entrée : {reponse}")
        
        if reponse.isdigit() and int(reponse) > 0:
            return int(reponse)
        else:
            print("Veuillez entrer un nombre positif valide.")
        
        index += 1
    
    return None

nombre = saisir_nombre()
if nombre:
    print(f"\nNombre valide saisi : {nombre}")

# %% [markdown]
# ### 2.2 Boucles infinies

# %%
# Exemple : boucle avec condition de sortie
# ATTENTION : ne pas exécuter sans condition de sortie !

# Boucle infinie (commentée pour éviter le blocage)
# while True:
#     print("Cette boucle ne s'arrête jamais !")

# Boucle avec break pour sortir
compteur = 0
while True:
    print(f"Itération {compteur}")
    compteur += 1
    
    if compteur >= 5:
        print("Sortie de la boucle")
        break

# %% [markdown]
# ## 3. Contrôle du flux : break, continue, pass

# %% [markdown]
# ### 3.1 break - Sortir de la boucle

# %%
# break : sort immédiatement de la boucle
print("Recherche du nombre 5 :")
for i in range(10):
    print(i, end=' ')
    if i == 5:
        print("\nTrouvé ! Arrêt de la recherche.")
        break
else:
    print("\nNon trouvé")

# %%
# Exemple pratique : recherche dans une liste
utilisateurs = [
    {'nom': 'Alice', 'id': 1},
    {'nom': 'Bob', 'id': 2},
    {'nom': 'Charlie', 'id': 3},
    {'nom': 'David', 'id': 4}
]

id_recherche = 3
utilisateur_trouve = None

for user in utilisateurs:
    if user['id'] == id_recherche:
        utilisateur_trouve = user
        break

if utilisateur_trouve:
    print(f"Utilisateur trouvé : {utilisateur_trouve['nom']}")
else:
    print("Utilisateur non trouvé")

# %% [markdown]
# ### 3.2 continue - Passer à l'itération suivante

# %%
# continue : passe immédiatement à l'itération suivante
print("Nombres impairs de 0 à 9 :")
for i in range(10):
    if i % 2 == 0:  # Si pair
        continue  # Passe à l'itération suivante
    print(i, end=' ')
print()

# %%
# Exemple pratique : traiter seulement certains éléments
fichiers = ['data.csv', 'readme.txt', 'config.json', 'image.png', 'report.csv']

print("Fichiers CSV :")
for fichier in fichiers:
    if not fichier.endswith('.csv'):
        continue  # Ignore les fichiers non-CSV
    
    print(f"  Traitement de {fichier}")

# %% [markdown]
# ### 3.3 pass - Instruction vide

# %%
# pass : ne fait rien (placeholder)
# Utile pendant le développement

for i in range(5):
    if i == 2:
        pass  # TODO : implémenter plus tard
    else:
        print(i)

# %%
# pass dans une fonction ou classe (définition minimale)
def fonction_a_implementer():
    pass  # Placeholder

class ClasseAImplementer:
    pass  # Placeholder

# Le code ne fait rien mais est syntaxiquement correct
fonction_a_implementer()
obj = ClasseAImplementer()
print("Code exécuté sans erreur")

# %% [markdown]
# ## 4. Clause else sur les boucles
#
# En Python, les boucles `for` et `while` peuvent avoir une clause `else` qui s'exécute **uniquement si la boucle se termine normalement** (sans `break`).

# %%
# for...else : else s'exécute si aucun break n'est rencontré
print("Recherche du nombre 15 :")
for i in range(10):
    if i == 15:
        print(f"Trouvé : {i}")
        break
else:
    print("Non trouvé dans la plage")

# %%
# Exemple avec break
print("\nRecherche du nombre 5 :")
for i in range(10):
    if i == 5:
        print(f"Trouvé : {i}")
        break
else:
    print("Non trouvé dans la plage")

# %%
# Exemple pratique : vérifier si un nombre est premier
def est_premier(n):
    """
    Vérifie si n est un nombre premier.
    """
    if n < 2:
        return False
    
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False  # Divisible, donc pas premier
    else:
        return True  # Aucun diviseur trouvé, donc premier

# Tests
nombres = [2, 7, 12, 17, 20, 23]
for nombre in nombres:
    resultat = "premier" if est_premier(nombre) else "non premier"
    print(f"{nombre} est {resultat}")

# %%
# while...else
compteur = 0
cible = 15

print(f"Recherche de {cible} :")
while compteur < 10:
    if compteur == cible:
        print(f"Trouvé : {cible}")
        break
    compteur += 1
else:
    print(f"{cible} non trouvé dans la plage")

# %% [markdown]
# ## 5. Boucles imbriquées

# %%
# Boucles imbriquées simples
print("Table de multiplication (1 à 5) :\n")
for i in range(1, 6):
    for j in range(1, 6):
        resultat = i * j
        print(f"{resultat:3}", end=' ')
    print()  # Nouvelle ligne après chaque ligne

# %%
# Parcourir une matrice
matrice = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print("Parcours de matrice :")
for i, ligne in enumerate(matrice):
    for j, valeur in enumerate(ligne):
        print(f"matrice[{i}][{j}] = {valeur}")

# %%
# break dans une boucle imbriquée (ne sort que de la boucle interne)
print("\nRecherche dans une matrice :")
matrice = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

cible = 5
trouve = False

for i, ligne in enumerate(matrice):
    for j, valeur in enumerate(ligne):
        if valeur == cible:
            print(f"Trouvé {cible} à [{i}][{j}]")
            trouve = True
            break
    if trouve:
        break
else:
    print(f"{cible} non trouvé")

# %% [markdown]
# ## 6. Itération sur des dictionnaires

# %%
# Créer un dictionnaire pour les exemples
personne = {
    'nom': 'Alice',
    'age': 25,
    'ville': 'Paris',
    'profession': 'Data Engineer'
}

# %%
# Itérer sur les clés (par défaut)
print("Clés :")
for cle in personne:
    print(f"  {cle}")

# Équivalent avec .keys()
print("\nClés avec .keys() :")
for cle in personne.keys():
    print(f"  {cle}")

# %%
# Itérer sur les valeurs
print("Valeurs :")
for valeur in personne.values():
    print(f"  {valeur}")

# %%
# Itérer sur les paires clé-valeur
print("Paires clé-valeur :")
for cle, valeur in personne.items():
    print(f"  {cle}: {valeur}")

# %%
# Exemple pratique : filtrer un dictionnaire
notes = {
    'Alice': 15,
    'Bob': 12,
    'Charlie': 18,
    'David': 9,
    'Eve': 16
}

# Étudiants ayant réussi (>= 10)
print("Étudiants ayant réussi :")
for nom, note in notes.items():
    if note >= 10:
        print(f"  {nom}: {note}/20")

# %% [markdown]
# ## 7. Pièges Courants ⚠️

# %% [markdown]
# ### Piège 1 : Modifier une liste pendant l'itération

# %%
# INCORRECT : modifier la liste pendant l'itération
nombres = [1, 2, 3, 4, 5, 6]
print("Liste originale :", nombres)

# Ceci peut causer des problèmes
for i, nombre in enumerate(nombres[:]):  # Utiliser une copie
    if nombre % 2 == 0:
        nombres.remove(nombre)

print("Après suppression des pairs (avec copie) :", nombres)

# %%
# CORRECT : utiliser une list comprehension
nombres = [1, 2, 3, 4, 5, 6]
print("Liste originale :", nombres)

nombres = [n for n in nombres if n % 2 != 0]
print("Après suppression des pairs (comprehension) :", nombres)

# %%
# CORRECT : créer une nouvelle liste
nombres = [1, 2, 3, 4, 5, 6]
print("Liste originale :", nombres)

nombres_impairs = []
for nombre in nombres:
    if nombre % 2 != 0:
        nombres_impairs.append(nombre)

print("Nombres impairs (nouvelle liste) :", nombres_impairs)

# %% [markdown]
# ### Piège 2 : range() off-by-one

# %%
# Erreur courante : oublier que range(n) va de 0 à n-1
liste = [10, 20, 30, 40, 50]

# INCORRECT : dépassement d'index
# for i in range(len(liste) + 1):  # ERREUR : IndexError
#     print(liste[i])

# CORRECT
print("Avec range(len(liste)) :")
for i in range(len(liste)):
    print(f"  Index {i}: {liste[i]}")

# MEILLEUR : itérer directement
print("\nItération directe :")
for valeur in liste:
    print(f"  {valeur}")

# %% [markdown]
# ### Piège 3 : Boucle infinie

# %%
# INCORRECT : oublier d'incrémenter le compteur
# compteur = 0
# while compteur < 5:
#     print(compteur)  # Boucle infinie : compteur ne change jamais !

# CORRECT
compteur = 0
while compteur < 5:
    print(compteur, end=' ')
    compteur += 1  # Ne pas oublier !
print()

# %% [markdown]
# ### Piège 4 : Mauvaise utilisation de enumerate()

# %%
# INCORRECT : utiliser range(len()) au lieu de enumerate()
fruits = ['pomme', 'banane', 'orange']

# Pas pythonique
print("Avec range(len()) :")
for i in range(len(fruits)):
    print(f"  {i}: {fruits[i]}")

# CORRECT : utiliser enumerate()
print("\nAvec enumerate() :")
for i, fruit in enumerate(fruits):
    print(f"  {i}: {fruit}")

# %% [markdown]
# ## 8. Mini-Exercices 🎯

# %% [markdown]
# ### Exercice 1 : Table de multiplication
#
# Créez une fonction qui affiche la table de multiplication d'un nombre donné de 1 à 10.
#
# Format attendu pour `table_multiplication(7)` :
# ```
# 7 x 1 = 7
# 7 x 2 = 14
# ...
# 7 x 10 = 70
# ```

# %%
# VOTRE CODE ICI
def table_multiplication(n):
    """
    Affiche la table de multiplication de n.
    
    Args:
        n: Nombre dont on veut la table de multiplication
    """
    pass

# Test
table_multiplication(7)

# %% [markdown]
# ### Solution Exercice 1

# %%
def table_multiplication(n):
    """
    Affiche la table de multiplication de n.
    
    Args:
        n: Nombre dont on veut la table de multiplication
    """
    print(f"Table de multiplication de {n} :\n")
    for i in range(1, 11):
        resultat = n * i
        print(f"{n} x {i:2} = {resultat}")

# Tests
table_multiplication(7)
print()
table_multiplication(12)

# %% [markdown]
# ### Exercice 2 : FizzBuzz
#
# Implémentez le célèbre jeu FizzBuzz :
# - Pour les nombres de 1 à 100
# - Si le nombre est divisible par 3, afficher "Fizz"
# - Si le nombre est divisible par 5, afficher "Buzz"
# - Si le nombre est divisible par 3 ET 5, afficher "FizzBuzz"
# - Sinon, afficher le nombre

# %%
# VOTRE CODE ICI
def fizzbuzz(n=100):
    """
    Joue à FizzBuzz de 1 à n.
    
    Args:
        n: Nombre maximum (défaut: 100)
    """
    pass

# Test
fizzbuzz(30)

# %% [markdown]
# ### Solution Exercice 2

# %%
def fizzbuzz(n=100):
    """
    Joue à FizzBuzz de 1 à n.
    
    Args:
        n: Nombre maximum (défaut: 100)
    """
    for i in range(1, n + 1):
        # Vérifier d'abord divisible par 3 ET 5
        if i % 3 == 0 and i % 5 == 0:
            print("FizzBuzz")
        elif i % 3 == 0:
            print("Fizz")
        elif i % 5 == 0:
            print("Buzz")
        else:
            print(i)

# Test
print("FizzBuzz de 1 à 30 :\n")
fizzbuzz(30)

# %% [markdown]
# ### Exercice 3 : Recherche linéaire
#
# Implémentez une fonction de recherche linéaire qui :
# 1. Cherche un élément dans une liste
# 2. Retourne l'index de la première occurrence
# 3. Retourne -1 si l'élément n'est pas trouvé
# 4. Affiche le nombre d'itérations effectuées

# %%
# VOTRE CODE ICI
def recherche_lineaire(liste, element):
    """
    Recherche linéaire d'un élément dans une liste.
    
    Args:
        liste: Liste dans laquelle chercher
        element: Élément à chercher
    
    Returns:
        int: Index de l'élément, ou -1 si non trouvé
    """
    pass

# Test
nombres = [10, 23, 45, 12, 78, 34, 90, 15]
print(recherche_lineaire(nombres, 34))
# Attendu : index 5, 6 itérations

# %% [markdown]
# ### Solution Exercice 3

# %%
def recherche_lineaire(liste, element):
    """
    Recherche linéaire d'un élément dans une liste.
    
    Args:
        liste: Liste dans laquelle chercher
        element: Élément à chercher
    
    Returns:
        int: Index de l'élément, ou -1 si non trouvé
    """
    iterations = 0
    
    for index, valeur in enumerate(liste):
        iterations += 1
        if valeur == element:
            print(f"Élément trouvé en {iterations} itération(s)")
            return index
    else:
        print(f"Élément non trouvé après {iterations} itération(s)")
        return -1

# Tests
nombres = [10, 23, 45, 12, 78, 34, 90, 15]

print("Recherche de 34 :")
index = recherche_lineaire(nombres, 34)
print(f"Index: {index}\n")

print("Recherche de 100 :")
index = recherche_lineaire(nombres, 100)
print(f"Index: {index}\n")

print("Recherche de 10 :")
index = recherche_lineaire(nombres, 10)
print(f"Index: {index}")

# %% [markdown]
# ## 📚 Récapitulatif
#
# ### Points clés à retenir :
#
# 1. **Boucle for** :
#    - Itération sur séquences : `for element in sequence`
#    - `range(start, stop, step)` pour générer des nombres
#    - `enumerate(iterable, start=0)` pour obtenir index + valeur
#    - `zip(*iterables)` pour itération parallèle
#
# 2. **Boucle while** :
#    - Continue tant que la condition est vraie
#    - Attention aux boucles infinies
#    - Toujours mettre à jour la condition
#
# 3. **Contrôle du flux** :
#    - `break` : sort de la boucle
#    - `continue` : passe à l'itération suivante
#    - `pass` : ne fait rien (placeholder)
#
# 4. **Clause else** :
#    - S'exécute si la boucle se termine sans `break`
#    - Utile pour la recherche
#
# 5. **Itération sur dictionnaires** :
#    - `.keys()` : itérer sur les clés
#    - `.values()` : itérer sur les valeurs
#    - `.items()` : itérer sur les paires clé-valeur
#
# ### Bonnes pratiques :
# - Préférer `enumerate()` à `range(len())`
# - Éviter de modifier une liste pendant l'itération
# - Utiliser des list comprehensions quand approprié
# - Attention aux boucles infinies avec `while`
# - Utiliser `for...else` pour les recherches
