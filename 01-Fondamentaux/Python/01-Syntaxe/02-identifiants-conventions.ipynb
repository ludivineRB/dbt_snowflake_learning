# %% [markdown]
# # 02 - Identifiants et Conventions
#
# 🟢 Débutant | ⏱ 45 min | 🔑 Concepts : PEP 8, nommage, indentation
#
# ## Objectifs
#
# - Comprendre les règles de nommage des identifiants en Python
# - Maîtriser les conventions PEP 8 (snake_case, CamelCase, UPPER_CASE)
# - Appliquer correctement l'indentation (règle des 4 espaces)
# - Utiliser les commentaires et docstrings efficacement
# - Identifier les mots réservés du langage
# - Éviter les pièges courants de nommage et d'indentation
#
# ## Prérequis
#
# - Avoir suivi le notebook 01 (Introduction et Installation)
# - Savoir exécuter du code Python

# %% [markdown]
# ## 1. Identifiants : Règles de Nommage
#
# Un **identifiant** est un nom donné à une variable, fonction, classe, module, etc.
#
# ### Règles syntaxiques (obligatoires)
#
# 1. **Commence par** : une lettre (a-z, A-Z) ou un underscore (_)
# 2. **Peut contenir** : lettres, chiffres (0-9), underscores (_)
# 3. **Ne peut pas contenir** : espaces, caractères spéciaux (@, #, %, etc.)
# 4. **Sensible à la casse** : `nom`, `Nom`, `NOM` sont trois identifiants différents
# 5. **Pas de mot réservé** : ne peut pas être un keyword Python (if, for, class, etc.)
#
# ### Exemples valides et invalides

# %%
# ✅ IDENTIFIANTS VALIDES

nom = "Alice"
nom_complet = "Alice Dupont"
age2 = 25
_variable_privee = 42
__variable_tres_privee = 100
PI = 3.14159
MaClasse = "exemple"

print("Tous les identifiants ci-dessus sont valides")

# %%
# ❌ IDENTIFIANTS INVALIDES (décommentez pour voir les erreurs)

# 2age = 25              # Commence par un chiffre
# nom-complet = "Alice"  # Contient un tiret
# mon nom = "Bob"        # Contient un espace
# @variable = 10         # Commence par @
# for = 5                # Mot réservé

print("Décommentez les lignes ci-dessus pour voir les erreurs")

# %% [markdown]
# ### Sensibilité à la casse

# %%
# Ce sont trois variables DIFFÉRENTES
nom = "Alice"
Nom = "Bob"
NOM = "Charlie"

print(f"nom = {nom}")
print(f"Nom = {Nom}")
print(f"NOM = {NOM}")

# %% [markdown]
# ## 2. PEP 8 : Le Guide de Style Python
#
# **PEP 8** (Python Enhancement Proposal 8) est le guide de style officiel de Python. Il définit des conventions pour rendre le code plus lisible et cohérent.
#
# ### Les différentes conventions de nommage
#
# | Type | Convention | Exemple |
# |------|------------|----------|
# | **Variables** | snake_case | `ma_variable`, `nombre_total` |
# | **Fonctions** | snake_case | `calculer_moyenne()`, `afficher_resultat()` |
# | **Constantes** | UPPER_SNAKE_CASE | `PI`, `MAX_SIZE`, `API_KEY` |
# | **Classes** | PascalCase (CamelCase) | `MaClasse`, `UtilisateurActif` |
# | **Modules** | snake_case | `mon_module.py`, `utils.py` |
# | **Privé** | Préfixe _ | `_variable_privee`, `_methode_interne()` |
# | **Très privé** | Préfixe __ | `__variable_tres_privee` |

# %% [markdown]
# ### snake_case (variables et fonctions)

# %%
# ✅ BON : snake_case pour les variables et fonctions
prenom_utilisateur = "Alice"
age_en_annees = 25
est_actif = True

def calculer_somme(a, b):
    """Calcule la somme de deux nombres."""
    return a + b

def obtenir_nom_complet(prenom, nom):
    """Retourne le nom complet."""
    return f"{prenom} {nom}"

print(obtenir_nom_complet("Alice", "Dupont"))

# %%
# ❌ MAUVAIS : Mélange de conventions
PrenomUtilisateur = "Bob"  # Devrait être prenom_utilisateur
AgeEnAnnees = 30           # Devrait être age_en_annees

def CalculerSomme(a, b):   # Devrait être calculer_somme
    return a + b

# Ce code fonctionne, mais ne suit pas PEP 8

# %% [markdown]
# ### UPPER_CASE (constantes)

# %%
# ✅ BON : UPPER_CASE pour les constantes
PI = 3.14159
VITESSE_LUMIERE = 299792458  # m/s
MAX_TENTATIVES = 3
TIMEOUT_SECONDES = 30
API_URL = "https://api.example.com"

# Utilisation
rayon = 5
circonference = 2 * PI * rayon
print(f"Circonférence : {circonference:.2f}")

# %% [markdown]
# ### PascalCase / CamelCase (classes)

# %%
# ✅ BON : PascalCase pour les classes
class Utilisateur:
    """Représente un utilisateur."""
    pass

class CompteBancaire:
    """Représente un compte bancaire."""
    pass

class GestionnaireBaseDonnees:
    """Gère les connexions à la base de données."""
    pass

# Création d'instances
utilisateur = Utilisateur()
compte = CompteBancaire()
print("Classes créées selon PEP 8")

# %% [markdown]
# ## 3. Indentation : La Règle des 4 Espaces
#
# En Python, **l'indentation n'est pas optionnelle** : elle définit la structure du code (blocs, fonctions, boucles, etc.).
#
# ### Règle PEP 8 : 4 espaces par niveau d'indentation
#
# - ✅ Utilisez **4 espaces** (pas de tabulation)
# - ❌ Ne mélangez jamais espaces et tabulations
# - ⚠️ La plupart des éditeurs peuvent être configurés pour convertir Tab en 4 espaces

# %%
# ✅ BON : Indentation correcte avec 4 espaces
def saluer(nom):
    if nom:
        message = f"Bonjour, {nom} !"
        print(message)
    else:
        print("Bonjour, inconnu !")

saluer("Alice")
saluer("")

# %%
# ❌ MAUVAIS : Indentation incorrecte (décommentez pour voir l'erreur)

# def saluer(nom):
# if nom:  # IndentationError: attendu une indentation
#     print(f"Bonjour, {nom} !")

print("L'indentation est OBLIGATOIRE en Python")

# %% [markdown]
# ### Niveaux d'indentation multiples

# %%
# Chaque niveau d'imbrication ajoute 4 espaces
def analyser_note(note):
    """Analyse une note et affiche un message."""
    if note >= 0 and note <= 20:
        if note >= 16:
            print("Excellent !")
        elif note >= 14:
            print("Très bien")
        elif note >= 12:
            print("Bien")
        elif note >= 10:
            print("Passable")
        else:
            print("Insuffisant")
    else:
        print("Note invalide")

analyser_note(15)
analyser_note(8)
analyser_note(25)

# %% [markdown]
# ## 4. Commentaires et Documentation
#
# ### Commentaires sur une ligne (#)

# %%
# Ceci est un commentaire sur une ligne
# Il explique le code mais n'est pas exécuté

prix_ht = 100  # Prix hors taxes
tva = 0.20     # Taux de TVA (20%)

# Calcul du prix TTC
prix_ttc = prix_ht * (1 + tva)
print(f"Prix TTC : {prix_ttc} €")

# %% [markdown]
# ### Docstrings (documentation de fonction)

# %%
def calculer_prix_ttc(prix_ht, taux_tva=0.20):
    """
    Calcule le prix TTC à partir du prix HT.
    
    Args:
        prix_ht (float): Prix hors taxes
        taux_tva (float): Taux de TVA (par défaut 0.20 pour 20%)
    
    Returns:
        float: Prix toutes taxes comprises
    
    Example:
        >>> calculer_prix_ttc(100)
        120.0
    """
    return prix_ht * (1 + taux_tva)

# Accéder à la docstring
print(calculer_prix_ttc.__doc__)

# %% [markdown]
# ### Commentaires multi-lignes

# %%
"""
Ceci est un commentaire multi-lignes.
Il peut s'étendre sur plusieurs lignes.
Utilisé souvent en début de fichier ou de fonction.
"""

'''
On peut aussi utiliser des guillemets simples triples.
C'est équivalent aux guillemets doubles triples.
'''

print("Les commentaires multi-lignes sont utiles pour la documentation")

# %% [markdown]
# ### Bonnes pratiques de commentaires
#
# ✅ **BON** :
# ```python
# # Convertit les kilomètres en miles (1 km = 0.621371 miles)
# miles = kilometres * 0.621371
# ```
#
# ❌ **MAUVAIS** :
# ```python
# # Multiplie kilometres par 0.621371
# miles = kilometres * 0.621371  # Commentaire redondant
# ```
#
# **Règle :** Commentez le "pourquoi", pas le "quoi" (le code montre déjà ce qu'il fait).

# %% [markdown]
# ## 5. Blocs de Code
#
# En Python, les blocs de code sont définis par :
# 1. **Deux-points (:)** à la fin de la ligne d'en-tête
# 2. **Indentation** pour le contenu du bloc

# %%
# Exemple de différents blocs

# Bloc if
age = 18
if age >= 18:
    print("Majeur")
    print("Peut voter")

# Bloc fonction
def dire_bonjour():
    print("Bonjour !")
    print("Comment allez-vous ?")

# Bloc boucle
for i in range(3):
    print(f"Itération {i}")

dire_bonjour()

# %% [markdown]
# ## 6. Mots Réservés (Keywords)
#
# Python possède 35 mots réservés qui ne peuvent pas être utilisés comme identifiants.

# %%
# Liste complète des mots réservés
import keyword

print("Nombre de mots réservés :", len(keyword.kwlist))
print("\nListe des mots réservés :")
for i, kw in enumerate(keyword.kwlist, 1):
    print(f"{i:2}. {kw}", end="  ")
    if i % 5 == 0:
        print()  # Saut de ligne tous les 5 mots

# %%
# Vérifier si un mot est réservé
print(keyword.iskeyword("for"))      # True
print(keyword.iskeyword("print"))    # False
print(keyword.iskeyword("variable")) # False

# %%
# ❌ ERREUR : Utiliser un mot réservé comme variable (décommentez)

# for = 10        # SyntaxError: invalid syntax
# class = "test"  # SyntaxError: invalid syntax
# if = True       # SyntaxError: invalid syntax

print("Ne jamais utiliser les mots réservés comme variables !")

# %% [markdown]
# ## 7. Conventions Additionnelles PEP 8
#
# ### Longueur de ligne

# %%
# ✅ BON : Maximum 79 caractères par ligne (PEP 8)
resultat = (
    premiere_valeur + deuxieme_valeur + troisieme_valeur
    + quatrieme_valeur + cinquieme_valeur
)

# Alternative avec backslash
message = "Ceci est un message très long qui dépasse " \
          "la limite de 79 caractères par ligne"

print(message)

# %% [markdown]
# ### Espaces autour des opérateurs

# %%
# ✅ BON : Espaces autour des opérateurs
x = 5
y = x + 10
z = x * y - 3

# ❌ MAUVAIS : Pas d'espaces
x=5
y=x+10
z=x*y-3

# Exception : Pas d'espace pour les arguments par défaut
def fonction(a, b=10, c=20):
    return a + b + c

print(fonction(5))

# %% [markdown]
# ### Lignes vides

# %%
# ✅ BON : 2 lignes vides avant une fonction de premier niveau


def fonction_un():
    """Première fonction."""
    pass


def fonction_deux():
    """Deuxième fonction."""
    pass


# Une ligne vide pour séparer des groupes logiques
x = 10
y = 20

resultat = x + y
print(resultat)

# %% [markdown]
# ## 8. Pièges Courants
#
# ### Piège 1 : Mélanger tabs et espaces

# %%
# ⚠️ ATTENTION : Ce code peut sembler correct visuellement,
# mais mélange tabs et espaces (peut causer TabError)

def fonction_dangereuse():
    print("Ligne 1")  # 4 espaces
    print("Ligne 2")  # 1 tab (peut ressembler à 4 espaces)
    # Python 3 rejette ce mélange !

# Solution : Configurez votre éditeur pour convertir Tab en 4 espaces
print("Utilisez TOUJOURS des espaces, jamais de tabs")

# %% [markdown]
# ### Piège 2 : Utiliser des noms de built-ins

# %%
# ❌ MAUVAIS : Écraser une fonction built-in
# print = "valeur"  # Maintenant print() ne fonctionne plus !
# list = [1, 2, 3]  # list() ne fonctionne plus !

# ✅ BON : Utilisez des noms différents
message_to_print = "valeur"
my_list = [1, 2, 3]

print("N'écrasez jamais les fonctions built-in !")

# %% [markdown]
# ### Piège 3 : Noms trop courts ou trop longs

# %%
# ❌ MAUVAIS : Noms cryptiques
a = 100
b = 0.20
c = a * (1 + b)

# ✅ BON : Noms descriptifs
prix_ht = 100
taux_tva = 0.20
prix_ttc = prix_ht * (1 + taux_tva)

# ❌ MAUVAIS : Trop long
le_prix_total_toutes_taxes_comprises_de_mon_produit = 120

# ✅ BON : Équilibre
prix_ttc_produit = 120

print(f"Prix TTC : {prix_ttc} €")

# %% [markdown]
# ### Piège 4 : Indentation incohérente

# %%
# ❌ ERREUR : Indentation incohérente (décommentez)

# def ma_fonction():
#     print("Ligne 1")  # 4 espaces
#       print("Ligne 2")  # 6 espaces - IndentationError !

# ✅ BON : Indentation cohérente
def ma_fonction():
    print("Ligne 1")  # 4 espaces
    print("Ligne 2")  # 4 espaces
    if True:
        print("Ligne 3")  # 8 espaces (4 + 4)

ma_fonction()

# %% [markdown]
# ## 9. Mini-Exercices
#
# ### Exercice 1 : Identifier les erreurs de nommage
#
# Parmi ces identifiants, lesquels sont **invalides** ? Pourquoi ?
#
# ```python
# 1. mon_age
# 2. 2eme_variable
# 3. prenom_nom
# 4. mon-identifiant
# 5. _variable_privee
# 6. class
# 7. MonNom
# 8. mon@email
# ```

# %%
# Votre réponse ici (testez chaque identifiant)

# %% [markdown]
# ### Exercice 2 : Corriger l'indentation
#
# Le code suivant a des problèmes d'indentation. Corrigez-le.

# %%
# Code à corriger (décommentez et corrigez)

# def calculer_moyenne(notes):
# total = 0
# for note in notes:
# total += note
#   moyenne = total / len(notes)
#     return moyenne

# Votre code corrigé ici

# %% [markdown]
# ### Exercice 3 : Appliquer PEP 8
#
# Refactorisez ce code pour qu'il respecte PEP 8 :
# - Conventions de nommage
# - Espaces autour des opérateurs
# - Commentaires appropriés

# %%
# Code à refactoriser
PrixHT=100
TAUX=0.20
def CalculPrixTTC(p,t):
    R=p*(1+t)
    return R
PrixFinal=CalculPrixTTC(PrixHT,TAUX)
print(PrixFinal)

# Votre code refactorisé ici

# %% [markdown]
# ## Solutions
#
# ### Solution Exercice 1

# %%
# Identifiants INVALIDES :

# 2. 2eme_variable     -> ❌ Commence par un chiffre
# 4. mon-identifiant   -> ❌ Contient un tiret (-)
# 6. class             -> ❌ Mot réservé Python
# 8. mon@email         -> ❌ Contient @ (caractère spécial)

# Identifiants VALIDES :
mon_age = 25                # ✅
prenom_nom = "Alice"        # ✅
_variable_privee = 42       # ✅
MonNom = "Bob"              # ✅ (mais devrait être mon_nom selon PEP 8)

# Corrections suggérées :
deuxieme_variable = 10      # Au lieu de 2eme_variable
mon_identifiant = "test"    # Au lieu de mon-identifiant
ma_classe = "Python"        # Au lieu de class
mon_email = "a@b.com"       # Au lieu de mon@email

print("Exercice 1 : corrigé")

# %% [markdown]
# ### Solution Exercice 2

# %%
# Code corrigé avec indentation appropriée
def calculer_moyenne(notes):
    """Calcule la moyenne d'une liste de notes."""
    total = 0
    for note in notes:
        total += note
    moyenne = total / len(notes)
    return moyenne

# Test
mes_notes = [15, 12, 18, 14]
print(f"Moyenne : {calculer_moyenne(mes_notes):.2f}")

# %% [markdown]
# ### Solution Exercice 3

# %%
# Code refactorisé selon PEP 8

# Constante en UPPER_CASE
TAUX_TVA = 0.20

# Variable en snake_case
prix_ht = 100

def calculer_prix_ttc(prix_ht, taux_tva):
    """
    Calcule le prix TTC à partir du prix HT et du taux de TVA.
    
    Args:
        prix_ht (float): Prix hors taxes
        taux_tva (float): Taux de TVA (ex: 0.20 pour 20%)
    
    Returns:
        float: Prix toutes taxes comprises
    """
    # Formule : prix_ttc = prix_ht * (1 + taux_tva)
    prix_ttc = prix_ht * (1 + taux_tva)
    return prix_ttc

# Calcul et affichage
prix_final = calculer_prix_ttc(prix_ht, TAUX_TVA)
print(f"Prix TTC : {prix_final} €")

# %% [markdown]
# ## Récapitulatif
#
# Dans ce notebook, vous avez appris :
#
# ✅ Les règles syntaxiques pour les identifiants valides
# ✅ Les conventions PEP 8 : snake_case, PascalCase, UPPER_CASE
# ✅ L'importance de l'indentation (4 espaces obligatoires)
# ✅ Comment écrire des commentaires et docstrings efficaces
# ✅ Les mots réservés de Python à éviter
# ✅ Les pièges courants : mélange tabs/espaces, noms réservés, etc.
#
# **Prochaine étape :** Apprendre les variables et les types numériques (int, float, bool).
