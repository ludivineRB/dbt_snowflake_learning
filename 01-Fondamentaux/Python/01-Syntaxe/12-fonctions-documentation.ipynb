# %% [markdown]
# # 🟢 Fonctions et Documentation en Python
#
# **Badge:** 🟢 Débutant | ⏱ 60 min | 🔑 **Concepts:** def, arguments, return, docstrings, scope
#
# ---
#
# ## 📋 Objectifs
#
# À la fin de ce notebook, vous serez capable de :
# - Définir et appeler des fonctions
# - Utiliser différents types de paramètres et arguments
# - Maîtriser `*args` et `**kwargs`
# - Retourner des valeurs simples et multiples
# - Écrire des docstrings claires et complètes
# - Comprendre la portée des variables (LEGB)
# - Utiliser `global` et `nonlocal`
# - Traiter les fonctions comme des objets de première classe
#
# ## 🎯 Prérequis
#
# - Connaissance des types de base
# - Compréhension des conditions et boucles
# - Familiarité avec les structures de données (listes, dicts, tuples)

# %% [markdown]
# ## 1. Définition et Appel de Fonctions

# %% [markdown]
# ### 1.1 Syntaxe de base

# %%
# Fonction simple sans paramètre
def dire_bonjour():
    """Affiche un message de bienvenue."""
    print("Bonjour tout le monde !")

# Appel de la fonction
dire_bonjour()

# %%
# Fonction avec paramètres
def dire_bonjour_a(nom):
    """Affiche un message de bienvenue personnalisé."""
    print(f"Bonjour {nom} !")

# Appel avec argument
dire_bonjour_a("Alice")
dire_bonjour_a("Bob")

# %%
# Fonction avec plusieurs paramètres
def presenter(prenom, nom, age):
    """Affiche une présentation complète."""
    print(f"Je m'appelle {prenom} {nom} et j'ai {age} ans.")

# Appel avec arguments positionnels
presenter("Alice", "Martin", 25)

# %% [markdown]
# ### 1.2 Instruction return

# %%
# Fonction qui retourne une valeur
def additionner(a, b):
    """Retourne la somme de deux nombres."""
    return a + b

resultat = additionner(10, 5)
print(f"10 + 5 = {resultat}")

# %%
# Fonction sans return explicite retourne None
def fonction_sans_return():
    """Fonction qui ne retourne rien explicitement."""
    x = 10 + 5

resultat = fonction_sans_return()
print(f"Résultat: {resultat}")  # None
print(f"Type: {type(resultat)}")  # <class 'NoneType'>

# %%
# Return multiples (tuple)
def calculer_operations(a, b):
    """
    Retourne plusieurs opérations sur deux nombres.
    
    Returns:
        tuple: (somme, différence, produit, quotient)
    """
    somme = a + b
    difference = a - b
    produit = a * b
    quotient = a / b if b != 0 else None
    return somme, difference, produit, quotient

# Unpacking des résultats
s, d, p, q = calculer_operations(20, 4)
print(f"Somme: {s}")
print(f"Différence: {d}")
print(f"Produit: {p}")
print(f"Quotient: {q}")

# %%
# Return anticipé (early return)
def est_majeur(age):
    """
    Vérifie si une personne est majeure.
    
    Args:
        age: Âge de la personne
    
    Returns:
        bool: True si majeur, False sinon
    """
    if age < 0:
        print("Âge invalide")
        return False
    
    if age >= 18:
        return True
    
    return False

print(est_majeur(25))   # True
print(est_majeur(15))   # False
print(est_majeur(-5))   # False + message

# %% [markdown]
# ## 2. Paramètres et Arguments

# %% [markdown]
# ### 2.1 Arguments positionnels et nommés

# %%
def creer_profil(nom, age, ville):
    """
    Crée un profil utilisateur.
    
    Args:
        nom: Nom de l'utilisateur
        age: Âge de l'utilisateur
        ville: Ville de l'utilisateur
    """
    return f"{nom}, {age} ans, {ville}"

# Arguments positionnels (ordre important)
print(creer_profil("Alice", 25, "Paris"))

# Arguments nommés (ordre pas important)
print(creer_profil(ville="Lyon", nom="Bob", age=30))

# Mélange (positionnels d'abord, puis nommés)
print(creer_profil("Charlie", ville="Marseille", age=28))

# %% [markdown]
# ### 2.2 Valeurs par défaut

# %%
# Paramètres avec valeurs par défaut
def saluer(nom, message="Bonjour", ponctuation="!"):
    """
    Salue une personne avec un message personnalisable.
    
    Args:
        nom: Nom de la personne
        message: Message de salutation (défaut: "Bonjour")
        ponctuation: Ponctuation finale (défaut: "!")
    """
    return f"{message} {nom}{ponctuation}"

# Utiliser les valeurs par défaut
print(saluer("Alice"))

# Surcharger certaines valeurs
print(saluer("Bob", "Bonsoir"))
print(saluer("Charlie", ponctuation="..."))
print(saluer("David", "Salut", "?"))

# %%
# Fonction avec beaucoup de paramètres optionnels
def configurer_serveur(
    nom,
    port=8080,
    host="localhost",
    debug=False,
    timeout=30
):
    """
    Configure un serveur web.
    
    Args:
        nom: Nom du serveur
        port: Port d'écoute (défaut: 8080)
        host: Hôte (défaut: localhost)
        debug: Mode debug (défaut: False)
        timeout: Timeout en secondes (défaut: 30)
    """
    config = {
        'nom': nom,
        'port': port,
        'host': host,
        'debug': debug,
        'timeout': timeout
    }
    return config

# Configuration minimale
print(configurer_serveur("API"))

# Configuration personnalisée
print(configurer_serveur("API", port=3000, debug=True))

# %% [markdown]
# ### 2.3 *args - Arguments positionnels variables

# %%
# *args permet de passer un nombre variable d'arguments positionnels
def additionner_tous(*nombres):
    """
    Additionne un nombre variable de nombres.
    
    Args:
        *nombres: Nombres à additionner
    
    Returns:
        int/float: Somme des nombres
    """
    print(f"Type de nombres: {type(nombres)}")
    print(f"Valeur de nombres: {nombres}")
    return sum(nombres)

print(additionner_tous(1, 2, 3))
print()
print(additionner_tous(10, 20, 30, 40, 50))
print()
print(additionner_tous(1))  # Un seul argument
print()
print(additionner_tous())   # Aucun argument

# %%
# Combiner arguments normaux et *args
def creer_message(titre, *mots, separateur=" "):
    """
    Crée un message avec un titre et des mots.
    
    Args:
        titre: Titre du message
        *mots: Mots du message
        separateur: Séparateur entre les mots (défaut: espace)
    
    Returns:
        str: Message formaté
    """
    contenu = separateur.join(mots)
    return f"{titre}: {contenu}"

print(creer_message("Langages", "Python", "Java", "JavaScript"))
print(creer_message("Fruits", "pomme", "banane", "orange", separateur=", "))

# %% [markdown]
# ### 2.4 **kwargs - Arguments nommés variables

# %%
# **kwargs permet de passer un nombre variable d'arguments nommés
def afficher_infos(**informations):
    """
    Affiche des informations sous forme de paires clé-valeur.
    
    Args:
        **informations: Informations à afficher
    """
    print(f"Type de informations: {type(informations)}")
    print(f"Valeur de informations: {informations}")
    print("\nInformations :")
    for cle, valeur in informations.items():
        print(f"  {cle}: {valeur}")

afficher_infos(nom="Alice", age=25, ville="Paris")
print()
afficher_infos(langage="Python", version="3.10", framework="Django")

# %%
# Combiner tous les types d'arguments
def fonction_complete(arg1, arg2, *args, kwarg1="default", **kwargs):
    """
    Fonction démontrant tous les types d'arguments.
    
    Args:
        arg1: Premier argument positionnel obligatoire
        arg2: Deuxième argument positionnel obligatoire
        *args: Arguments positionnels supplémentaires
        kwarg1: Argument nommé avec valeur par défaut
        **kwargs: Arguments nommés supplémentaires
    """
    print(f"arg1: {arg1}")
    print(f"arg2: {arg2}")
    print(f"args: {args}")
    print(f"kwarg1: {kwarg1}")
    print(f"kwargs: {kwargs}")

fonction_complete(
    "A", "B",           # arg1, arg2
    "C", "D",           # args
    kwarg1="custom",    # kwarg1
    extra1="E",         # kwargs
    extra2="F"          # kwargs
)

# %%
# Unpacking avec * et **
def creer_utilisateur(nom, age, ville):
    """Crée un utilisateur avec nom, âge et ville."""
    return f"Utilisateur: {nom}, {age} ans, {ville}"

# Unpacking d'une liste avec *
donnees_liste = ["Alice", 25, "Paris"]
print(creer_utilisateur(*donnees_liste))

# Unpacking d'un dictionnaire avec **
donnees_dict = {"nom": "Bob", "age": 30, "ville": "Lyon"}
print(creer_utilisateur(**donnees_dict))

# %% [markdown]
# ## 3. Docstrings - Documentation

# %% [markdown]
# ### 3.1 Format Google Style

# %%
def calculer_moyenne(notes):
    """
    Calcule la moyenne d'une liste de notes.
    
    Cette fonction prend une liste de notes numériques et retourne
    leur moyenne arithmétique. Si la liste est vide, retourne 0.
    
    Args:
        notes (list): Liste de notes (int ou float)
    
    Returns:
        float: Moyenne des notes, ou 0 si la liste est vide
    
    Raises:
        TypeError: Si notes n'est pas une liste
        ValueError: Si la liste contient des valeurs non numériques
    
    Examples:
        >>> calculer_moyenne([10, 15, 20])
        15.0
        >>> calculer_moyenne([12, 14, 16, 18])
        15.0
        >>> calculer_moyenne([])
        0
    """
    if not isinstance(notes, list):
        raise TypeError("notes doit être une liste")
    
    if not notes:
        return 0
    
    try:
        return sum(notes) / len(notes)
    except TypeError:
        raise ValueError("La liste doit contenir uniquement des nombres")

# Tests
print(calculer_moyenne([10, 15, 20]))
print(calculer_moyenne([12, 14, 16, 18]))
print(calculer_moyenne([]))

# Afficher la docstring
print("\nDocstring:")
print(calculer_moyenne.__doc__)

# %% [markdown]
# ### 3.2 Format NumPy Style

# %%
def calculer_statistiques(donnees):
    """
    Calcule des statistiques de base sur un ensemble de données.
    
    Calcule la moyenne, le minimum et le maximum d'une liste de nombres.
    
    Parameters
    ----------
    donnees : list of float or int
        Liste de valeurs numériques à analyser
    
    Returns
    -------
    dict
        Dictionnaire contenant:
        - 'moyenne': float, moyenne des valeurs
        - 'min': float or int, valeur minimale
        - 'max': float or int, valeur maximale
        - 'count': int, nombre de valeurs
    
    Raises
    ------
    ValueError
        Si la liste est vide
    
    See Also
    --------
    calculer_moyenne : Calcule uniquement la moyenne
    
    Examples
    --------
    >>> calculer_statistiques([1, 2, 3, 4, 5])
    {'moyenne': 3.0, 'min': 1, 'max': 5, 'count': 5}
    
    >>> calculer_statistiques([10, 20, 30])
    {'moyenne': 20.0, 'min': 10, 'max': 30, 'count': 3}
    """
    if not donnees:
        raise ValueError("La liste ne peut pas être vide")
    
    return {
        'moyenne': sum(donnees) / len(donnees),
        'min': min(donnees),
        'max': max(donnees),
        'count': len(donnees)
    }

# Test
stats = calculer_statistiques([1, 2, 3, 4, 5])
print(stats)

# %%
# Accéder à la documentation avec help()
help(calculer_statistiques)

# %% [markdown]
# ## 4. Portée des Variables (Scope LEGB)

# %% [markdown]
# ### 4.1 LEGB Rule
#
# Python cherche les variables dans cet ordre :
# 1. **L**ocal : dans la fonction actuelle
# 2. **E**nclosing : dans les fonctions englobantes
# 3. **G**lobal : au niveau du module
# 4. **B**uilt-in : noms intégrés à Python

# %%
# Démonstration LEGB
x = "global"  # Global scope

def fonction_externe():
    x = "enclosing"  # Enclosing scope
    
    def fonction_interne():
        x = "local"  # Local scope
        print(f"Local: {x}")
    
    fonction_interne()
    print(f"Enclosing: {x}")

fonction_externe()
print(f"Global: {x}")

# Built-in scope (ex: len, print, etc.)
print(f"Built-in: {len([1, 2, 3])}")

# %%
# Scope local vs global
compteur = 0  # Variable globale

def incrementer():
    compteur = 1  # Variable locale (masque la globale)
    print(f"Dans la fonction: {compteur}")

incrementer()
print(f"Hors de la fonction: {compteur}")  # La variable globale n'a pas changé

# %% [markdown]
# ### 4.2 Mot-clé global

# %%
# Utiliser global pour modifier une variable globale
compteur = 0

def incrementer_global():
    global compteur  # Déclarer qu'on utilise la variable globale
    compteur += 1
    print(f"Dans la fonction: {compteur}")

print(f"Avant: {compteur}")
incrementer_global()
incrementer_global()
print(f"Après: {compteur}")

# %%
# Exemple pratique : compteur de visites
visites = 0

def enregistrer_visite(nom_page):
    """
    Enregistre une visite de page.
    
    Args:
        nom_page: Nom de la page visitée
    """
    global visites
    visites += 1
    print(f"Page '{nom_page}' visitée. Total: {visites} visites")

enregistrer_visite("Accueil")
enregistrer_visite("Profil")
enregistrer_visite("Contact")
print(f"\nNombre total de visites: {visites}")

# %% [markdown]
# ### 4.3 Mot-clé nonlocal

# %%
# nonlocal permet de modifier une variable dans le scope englobant
def fonction_externe():
    compteur = 0  # Variable dans le scope englobant
    
    def incrementer():
        nonlocal compteur  # Utiliser la variable du scope englobant
        compteur += 1
        return compteur
    
    print(f"Compteur initial: {compteur}")
    print(f"Après 1er appel: {incrementer()}")
    print(f"Après 2e appel: {incrementer()}")
    print(f"Après 3e appel: {incrementer()}")
    print(f"Compteur final: {compteur}")

fonction_externe()

# %%
# Exemple pratique : closure avec état
def creer_compteur():
    """
    Crée une fonction compteur avec état persistant.
    
    Returns:
        function: Fonction qui incrémente et retourne un compteur
    """
    compteur = 0
    
    def incrementer():
        nonlocal compteur
        compteur += 1
        return compteur
    
    return incrementer

# Créer deux compteurs indépendants
compteur1 = creer_compteur()
compteur2 = creer_compteur()

print("Compteur 1:")
print(compteur1())  # 1
print(compteur1())  # 2
print(compteur1())  # 3

print("\nCompteur 2:")
print(compteur2())  # 1
print(compteur2())  # 2

# %% [markdown]
# ## 5. Fonctions comme Objets de Première Classe

# %% [markdown]
# ### 5.1 Assigner des fonctions à des variables

# %%
# Les fonctions sont des objets
def dire_bonjour(nom):
    """Dit bonjour."""
    return f"Bonjour {nom}"

def dire_au_revoir(nom):
    """Dit au revoir."""
    return f"Au revoir {nom}"

# Assigner une fonction à une variable
salutation = dire_bonjour
print(salutation("Alice"))

# Changer la fonction
salutation = dire_au_revoir
print(salutation("Alice"))

# %% [markdown]
# ### 5.2 Passer des fonctions en argument

# %%
# Fonction qui prend une fonction en argument
def appliquer_operation(nombres, operation):
    """
    Applique une opération à chaque élément d'une liste.
    
    Args:
        nombres: Liste de nombres
        operation: Fonction à appliquer
    
    Returns:
        list: Liste des résultats
    """
    return [operation(n) for n in nombres]

# Définir des opérations
def doubler(x):
    return x * 2

def carre(x):
    return x ** 2

# Appliquer différentes opérations
nombres = [1, 2, 3, 4, 5]
print(f"Originaux: {nombres}")
print(f"Doublés: {appliquer_operation(nombres, doubler)}")
print(f"Carrés: {appliquer_operation(nombres, carre)}")

# %%
# Exemple avec sorted() et une fonction de tri personnalisée
etudiants = [
    {'nom': 'Alice', 'note': 15},
    {'nom': 'Bob', 'note': 18},
    {'nom': 'Charlie', 'note': 12},
    {'nom': 'David', 'note': 16}
]

# Fonction pour extraire la clé de tri
def obtenir_note(etudiant):
    return etudiant['note']

# Trier par note
etudiants_tries = sorted(etudiants, key=obtenir_note, reverse=True)

print("Étudiants triés par note (décroissant):")
for etudiant in etudiants_tries:
    print(f"  {etudiant['nom']}: {etudiant['note']}/20")

# %% [markdown]
# ### 5.3 Retourner des fonctions

# %%
# Fonction qui retourne une fonction
def creer_multiplicateur(facteur):
    """
    Crée une fonction qui multiplie par un facteur donné.
    
    Args:
        facteur: Facteur de multiplication
    
    Returns:
        function: Fonction de multiplication
    """
    def multiplicateur(x):
        return x * facteur
    return multiplicateur

# Créer des fonctions spécialisées
doubler = creer_multiplicateur(2)
tripler = creer_multiplicateur(3)
decupler = creer_multiplicateur(10)

print(f"doubler(5) = {doubler(5)}")
print(f"tripler(5) = {tripler(5)}")
print(f"decupler(5) = {decupler(5)}")

# %%
# Factory de validateurs
def creer_validateur(min_val, max_val):
    """
    Crée une fonction de validation de plage.
    
    Args:
        min_val: Valeur minimale
        max_val: Valeur maximale
    
    Returns:
        function: Fonction de validation
    """
    def valider(valeur):
        return min_val <= valeur <= max_val
    return valider

# Créer des validateurs spécialisés
valider_age = creer_validateur(0, 120)
valider_note = creer_validateur(0, 20)
valider_pourcentage = creer_validateur(0, 100)

print(f"Age 25 valide? {valider_age(25)}")
print(f"Age 150 valide? {valider_age(150)}")
print(f"Note 15 valide? {valider_note(15)}")
print(f"Note 25 valide? {valider_note(25)}")

# %% [markdown]
# ## 6. Pièges Courants ⚠️

# %% [markdown]
# ### Piège 1 : Argument par défaut mutable

# %%
# INCORRECT : liste mutable comme valeur par défaut
def ajouter_element_v1(element, liste=[]):
    """ATTENTION : bug potentiel !"""
    liste.append(element)
    return liste

# Le problème : la liste par défaut est partagée entre tous les appels
print(ajouter_element_v1(1))  # [1]
print(ajouter_element_v1(2))  # [1, 2] - Surprise ! La liste persiste
print(ajouter_element_v1(3))  # [1, 2, 3]

# %%
# CORRECT : utiliser None comme valeur par défaut
def ajouter_element_v2(element, liste=None):
    """Version corrigée."""
    if liste is None:
        liste = []
    liste.append(element)
    return liste

# Maintenant ça fonctionne correctement
print(ajouter_element_v2(1))  # [1]
print(ajouter_element_v2(2))  # [2]
print(ajouter_element_v2(3))  # [3]

# %% [markdown]
# ### Piège 2 : Oublier le return

# %%
# INCORRECT : oublier le return
def calculer_double_v1(x):
    """Calcule le double (mais ne retourne rien)."""
    x * 2  # Calcul fait mais résultat perdu

resultat = calculer_double_v1(5)
print(f"Résultat: {resultat}")  # None

# CORRECT : ajouter return
def calculer_double_v2(x):
    """Calcule le double."""
    return x * 2

resultat = calculer_double_v2(5)
print(f"Résultat: {resultat}")  # 10

# %% [markdown]
# ### Piège 3 : Confusion entre portée locale et globale

# %%
# Piège : modifier une variable globale sans 'global'
total = 100

def ajouter(valeur):
    # total = total + valeur  # ERREUR : UnboundLocalError
    # Python voit une affectation à 'total', donc le considère comme local
    # Mais on essaie de lire 'total' avant de l'assigner
    pass

# CORRECT : déclarer global
def ajouter_correct(valeur):
    global total
    total = total + valeur

print(f"Total avant: {total}")
ajouter_correct(50)
print(f"Total après: {total}")

# %% [markdown]
# ### Piège 4 : Ordre des paramètres

# %%
# INCORRECT : paramètre par défaut avant paramètre obligatoire
# def fonction_incorrecte(a=1, b):  # SyntaxError
#     pass

# CORRECT : paramètres obligatoires d'abord
def fonction_correcte(b, a=1):
    return f"a={a}, b={b}"

print(fonction_correcte(5))       # a=1, b=5
print(fonction_correcte(5, 10))   # a=10, b=5

# %% [markdown]
# ## 7. Mini-Exercices 🎯

# %% [markdown]
# ### Exercice 1 : Calculatrice modulaire
#
# Créez une calculatrice avec :
# 1. Des fonctions pour chaque opération (addition, soustraction, multiplication, division)
# 2. Une fonction `calculer()` qui prend une opération et des nombres
# 3. Une gestion d'erreur pour la division par zéro
# 4. Des docstrings complètes

# %%
# VOTRE CODE ICI
def addition(a, b):
    pass

def soustraction(a, b):
    pass

def multiplication(a, b):
    pass

def division(a, b):
    pass

def calculer(operation, a, b):
    pass

# Test
print(calculer('addition', 10, 5))
print(calculer('division', 10, 0))

# %% [markdown]
# ### Solution Exercice 1

# %%
def addition(a, b):
    """
    Additionne deux nombres.
    
    Args:
        a (float): Premier nombre
        b (float): Deuxième nombre
    
    Returns:
        float: Somme de a et b
    """
    return a + b

def soustraction(a, b):
    """
    Soustrait deux nombres.
    
    Args:
        a (float): Premier nombre
        b (float): Deuxième nombre
    
    Returns:
        float: Différence de a et b
    """
    return a - b

def multiplication(a, b):
    """
    Multiplie deux nombres.
    
    Args:
        a (float): Premier nombre
        b (float): Deuxième nombre
    
    Returns:
        float: Produit de a et b
    """
    return a * b

def division(a, b):
    """
    Divise deux nombres.
    
    Args:
        a (float): Numérateur
        b (float): Dénominateur
    
    Returns:
        float: Quotient de a et b
    
    Raises:
        ValueError: Si b est égal à 0
    """
    if b == 0:
        raise ValueError("Division par zéro impossible")
    return a / b

def calculer(operation, a, b):
    """
    Effectue une opération mathématique.
    
    Args:
        operation (str): Opération à effectuer ('addition', 'soustraction', etc.)
        a (float): Premier nombre
        b (float): Deuxième nombre
    
    Returns:
        float: Résultat de l'opération
    
    Raises:
        ValueError: Si l'opération est inconnue ou si division par zéro
    """
    operations = {
        'addition': addition,
        'soustraction': soustraction,
        'multiplication': multiplication,
        'division': division
    }
    
    if operation not in operations:
        raise ValueError(f"Opération inconnue: {operation}")
    
    return operations[operation](a, b)

# Tests
print(f"10 + 5 = {calculer('addition', 10, 5)}")
print(f"10 - 5 = {calculer('soustraction', 10, 5)}")
print(f"10 * 5 = {calculer('multiplication', 10, 5)}")
print(f"10 / 5 = {calculer('division', 10, 5)}")

# Test d'erreur
try:
    print(calculer('division', 10, 0))
except ValueError as e:
    print(f"Erreur: {e}")

# %% [markdown]
# ### Exercice 2 : Fonction avec *args et **kwargs
#
# Créez une fonction `creer_rapport()` qui :
# 1. Accepte un titre (obligatoire)
# 2. Accepte n'importe quel nombre de sections via *args
# 3. Accepte des métadonnées via **kwargs (auteur, date, version, etc.)
# 4. Retourne un rapport formaté sous forme de chaîne

# %%
# VOTRE CODE ICI
def creer_rapport(titre, *sections, **metadata):
    pass

# Test
rapport = creer_rapport(
    "Rapport Mensuel",
    "Introduction",
    "Analyse des données",
    "Conclusions",
    auteur="Alice",
    date="2024-01-15",
    version="1.0"
)
print(rapport)

# %% [markdown]
# ### Solution Exercice 2

# %%
def creer_rapport(titre, *sections, **metadata):
    """
    Crée un rapport formaté.
    
    Args:
        titre (str): Titre du rapport
        *sections: Sections du rapport
        **metadata: Métadonnées (auteur, date, version, etc.)
    
    Returns:
        str: Rapport formaté
    """
    # En-tête
    rapport = []
    rapport.append("=" * 60)
    rapport.append(f"  {titre.upper()}")
    rapport.append("=" * 60)
    rapport.append("")
    
    # Métadonnées
    if metadata:
        rapport.append("Métadonnées:")
        for cle, valeur in metadata.items():
            rapport.append(f"  {cle.capitalize()}: {valeur}")
        rapport.append("")
    
    # Sections
    if sections:
        rapport.append("Sections:")
        for i, section in enumerate(sections, 1):
            rapport.append(f"  {i}. {section}")
        rapport.append("")
    
    # Pied de page
    rapport.append("=" * 60)
    
    return "\n".join(rapport)

# Tests
rapport1 = creer_rapport(
    "Rapport Mensuel",
    "Introduction",
    "Analyse des données",
    "Conclusions",
    auteur="Alice Martin",
    date="2024-01-15",
    version="1.0"
)
print(rapport1)

print("\n" + "*" * 60 + "\n")

rapport2 = creer_rapport(
    "Rapport Trimestriel",
    "Q1 Performance",
    "Q2 Performance",
    auteur="Bob Dupont"
)
print(rapport2)

# %% [markdown]
# ### Exercice 3 : Décorateur simple
#
# Créez un décorateur `chronometre` qui :
# 1. Mesure le temps d'exécution d'une fonction
# 2. Affiche le temps écoulé
# 3. Retourne le résultat de la fonction
#
# Appliquez-le à une fonction qui calcule la somme des n premiers nombres.

# %%
# VOTRE CODE ICI
import time

def chronometre(fonction):
    pass

@chronometre
def calculer_somme(n):
    """Calcule la somme des n premiers nombres."""
    pass

# Test
resultat = calculer_somme(1000000)
print(f"Résultat: {resultat}")

# %% [markdown]
# ### Solution Exercice 3

# %%
import time

def chronometre(fonction):
    """
    Décorateur qui mesure le temps d'exécution d'une fonction.
    
    Args:
        fonction: Fonction à décorer
    
    Returns:
        function: Fonction décorée
    """
    def wrapper(*args, **kwargs):
        debut = time.time()
        resultat = fonction(*args, **kwargs)
        fin = time.time()
        temps_ecoule = fin - debut
        print(f"⏱ {fonction.__name__}() a pris {temps_ecoule:.6f} secondes")
        return resultat
    return wrapper

@chronometre
def calculer_somme_v1(n):
    """Calcule la somme des n premiers nombres (méthode 1: boucle)."""
    total = 0
    for i in range(1, n + 1):
        total += i
    return total

@chronometre
def calculer_somme_v2(n):
    """Calcule la somme des n premiers nombres (méthode 2: formule)."""
    return n * (n + 1) // 2

@chronometre
def calculer_somme_v3(n):
    """Calcule la somme des n premiers nombres (méthode 3: sum + range)."""
    return sum(range(1, n + 1))

# Tests comparatifs
n = 1000000
print(f"Calcul de la somme des {n:,} premiers nombres:\n")

resultat1 = calculer_somme_v1(n)
print(f"Résultat v1: {resultat1:,}\n")

resultat2 = calculer_somme_v2(n)
print(f"Résultat v2: {resultat2:,}\n")

resultat3 = calculer_somme_v3(n)
print(f"Résultat v3: {resultat3:,}")

# %% [markdown]
# ## 📚 Récapitulatif
#
# ### Points clés à retenir :
#
# 1. **Définition de fonctions** :
#    - `def nom_fonction(parametres):`
#    - `return` pour retourner une valeur
#    - Return multiple via tuple
#
# 2. **Types de paramètres** :
#    - Positionnels : ordre important
#    - Nommés : ordre pas important
#    - Par défaut : valeur optionnelle
#    - `*args` : arguments positionnels variables
#    - `**kwargs` : arguments nommés variables
#
# 3. **Documentation** :
#    - Docstrings avec triple quotes
#    - Google Style ou NumPy Style
#    - Args, Returns, Raises, Examples
#
# 4. **Portée (LEGB)** :
#    - Local : dans la fonction
#    - Enclosing : fonctions englobantes
#    - Global : niveau module
#    - Built-in : noms Python intégrés
#
# 5. **Mots-clés** :
#    - `global` : modifier une variable globale
#    - `nonlocal` : modifier une variable englobante
#
# 6. **Fonctions de première classe** :
#    - Assigner à des variables
#    - Passer en argument
#    - Retourner depuis une fonction
#
# ### Pièges à éviter :
# - Arguments par défaut mutables (utiliser `None`)
# - Oublier le `return`
# - Confusion entre portée locale et globale
# - Ordre incorrect des paramètres
#
# ### Bonnes pratiques :
# - Toujours écrire des docstrings
# - Une fonction = une responsabilité
# - Noms de fonctions explicites et en snake_case
# - Préférer le return explicite
# - Éviter les variables globales
