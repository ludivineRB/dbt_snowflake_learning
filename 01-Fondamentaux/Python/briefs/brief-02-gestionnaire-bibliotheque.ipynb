# %% [markdown]
# # ⚡ Brief 2 : Système de gestion de bibliothèque
#
# **Badge:** ⚡ Intermédiaire
# **Durée:** 3 heures
# **Sections validées:** 02-POO-Concepts + 03-POO-Python

# %% [markdown]
# ---
#
# ## 📋 Contexte
#
# Vous êtes développeur pour une **bibliothèque municipale** qui souhaite moderniser son système de gestion.
#
# Le système actuel est basé sur des fichiers Excel et des formulaires papier. La direction souhaite un système orienté objet en Python pour gérer :
# - Le catalogue de livres (physiques et numériques)
# - Les adhérents et leurs emprunts
# - Les notifications de retard
#
# **Votre mission :** Concevoir et implémenter un système POO complet avec tests.

# %% [markdown]
# ---
#
# ## 🎯 Objectifs du projet
#
# Développer un système orienté objet qui permet de :
#
# 1. ✅ Modéliser le domaine avec un diagramme UML
# 2. ✅ Gérer un catalogue de livres physiques et numériques
# 3. ✅ Gérer les adhérents et leurs emprunts
# 4. ✅ Implémenter l'héritage (Livre → LivreNumerique)
# 5. ✅ Utiliser l'encapsulation avec @property
# 6. ✅ Surcharger les méthodes spéciales (__str__, __repr__, etc.)
# 7. ✅ Créer des exceptions custom
# 8. ✅ Implémenter le pattern Observer pour les notifications
# 9. ✅ Écrire des tests unitaires avec pytest

# %% [markdown]
# ---
#
# ## 📝 Spécifications techniques
#
# ### 1. Modélisation UML
#
# Créer un diagramme de classes avec Mermaid représentant :
# - Les classes principales : Livre, Adherent, Emprunt, Bibliotheque
# - L'héritage : Livre → LivreNumerique
# - Les relations (composition, agrégation)
# - Les attributs et méthodes principales
#
# ### 2. Classe Livre
#
# **Attributs :**
# - `isbn` (str) : Identifiant unique
# - `titre` (str)
# - `auteur` (str)
# - `genre` (str)
# - `_disponible` (bool, privé)
#
# **Méthodes :**
# - `@property disponible` : Retourne si le livre est disponible
# - `emprunter()` : Marque le livre comme emprunté
# - `retourner()` : Marque le livre comme disponible
# - `__str__()` : Représentation lisible
# - `__repr__()` : Représentation technique
# - `__eq__()` : Comparaison par ISBN
#
# ### 3. Classe LivreNumerique (hérite de Livre)
#
# **Attributs supplémentaires :**
# - `format` (str) : PDF, EPUB, MOBI
# - `taille_mo` (float) : Taille du fichier
#
# **Particularité :**
# - Un livre numérique est toujours disponible (copies illimitées)
# - Surcharge de la méthode `emprunter()` pour ne pas changer la disponibilité
#
# ### 4. Classe Adherent
#
# **Attributs :**
# - `id` (str)
# - `nom` (str)
# - `prenom` (str)
# - `email` (str)
# - `_emprunts_en_cours` (List[Emprunt], privé)
# - `EMPRUNT_MAX` (constante de classe = 3)
#
# **Méthodes :**
# - `@property nombre_emprunts` : Retourne le nombre d'emprunts en cours
# - `@property peut_emprunter` : Retourne si l'adhérent peut emprunter (< 3)
# - `ajouter_emprunt(emprunt)` : Ajoute un emprunt
# - `retourner_livre(emprunt)` : Retire un emprunt de la liste
# - `__str__()` : Format lisible
#
# ### 5. Classe Emprunt
#
# **Attributs :**
# - `livre` (Livre)
# - `adherent` (Adherent)
# - `date_emprunt` (datetime)
# - `date_retour_prevue` (datetime) : date_emprunt + 21 jours
# - `date_retour_effective` (datetime | None)
#
# **Méthodes :**
# - `@property est_en_retard` : Retourne True si dépassé et non retourné
# - `@property jours_retard` : Nombre de jours de retard
# - `cloturer()` : Marque la date de retour effective
# - `__str__()` : Format lisible
#
# ### 6. Classe Bibliotheque
#
# **Attributs :**
# - `nom` (str)
# - `_catalogue` (Dict[str, Livre]) : ISBN → Livre
# - `_adherents` (Dict[str, Adherent]) : ID → Adherent
# - `_emprunts` (List[Emprunt])
# - `_observateurs` (List[Observer]) : Pour le pattern Observer
#
# **Méthodes :**
# - `ajouter_livre(livre)` : Ajoute un livre au catalogue
# - `ajouter_adherent(adherent)` : Ajoute un adhérent
# - `emprunter_livre(isbn, id_adherent)` : Crée un emprunt
# - `retourner_livre(isbn, id_adherent)` : Clôture un emprunt
# - `rechercher_livre(titre)` : Recherche par titre (partiel)
# - `livres_disponibles()` : Liste des livres disponibles
# - `verifier_retards()` : Notifie les observateurs pour les retards
# - `__len__()` : Nombre de livres dans le catalogue
# - `__str__()` : Statistiques de la bibliothèque
#
# ### 7. Exceptions custom
#
# Créer ces exceptions personnalisées :
#
# ```python
# class BibliothequeError(Exception):
#     """Exception de base pour la bibliothèque."""
#     pass
#
# class LivreIndisponibleError(BibliothequeError):
#     """Levée quand on tente d'emprunter un livre indisponible."""
#     pass
#
# class EmpruntMaxAtteintError(BibliothequeError):
#     """Levée quand un adhérent a atteint le max d'emprunts."""
#     pass
#
# class LivreInexistantError(BibliothequeError):
#     """Levée quand un livre n'existe pas dans le catalogue."""
#     pass
# ```
#
# ### 8. Pattern Observer
#
# Implémenter le pattern Observer pour notifier les retards :
#
# ```python
# class Observer(ABC):
#     @abstractmethod
#     def notifier(self, emprunt: Emprunt) -> None:
#         pass
#
# class NotificationEmail(Observer):
#     def notifier(self, emprunt: Emprunt) -> None:
#         # Simuler l'envoi d'email
#         print(f"📧 Email envoyé à {emprunt.adherent.email}")
#
# class NotificationSMS(Observer):
#     def notifier(self, emprunt: Emprunt) -> None:
#         # Simuler l'envoi de SMS
#         print(f"📱 SMS envoyé à {emprunt.adherent.nom}")
# ```

# %% [markdown]
# ---
#
# ## 📦 Livrables
#
# ### Checklist
#
# - [ ] Diagramme UML (Mermaid) complet et correct
# - [ ] Classe Livre implémentée avec @property
# - [ ] Classe LivreNumerique avec héritage
# - [ ] Classe Adherent avec encapsulation
# - [ ] Classe Emprunt fonctionnelle
# - [ ] Classe Bibliotheque avec toutes les méthodes
# - [ ] Méthodes spéciales (__str__, __repr__, __eq__, __len__)
# - [ ] 3 exceptions custom définies
# - [ ] Pattern Observer implémenté
# - [ ] Au moins 5 tests pytest qui passent
# - [ ] Type hints sur toutes les méthodes
# - [ ] Docstrings (format Google)
# - [ ] Code respectant PEP 8
# - [ ] Script de démonstration fonctionnel

# %% [markdown]
# ---
#
# ## 🎯 Grille d'évaluation
#
# | Compétence | Critères d'évaluation | Points |
# |------------|----------------------|--------|
# | **Modélisation UML** | Diagramme complet, relations correctes, clarté | **/15** |
# | **Héritage et polymorphisme** | LivreNumerique hérite correctement, surcharge méthodes | **/20** |
# | **Encapsulation** | Attributs privés, @property, validation | **/15** |
# | **Exceptions custom** | 3 exceptions définies et utilisées | **/10** |
# | **Méthodes spéciales** | __str__, __repr__, __eq__, __len__ | **/10** |
# | **Pattern Observer** | Implémentation correcte, découplage | **/10** |
# | **Tests unitaires** | 5+ tests pytest, coverage des cas | **/10** |
# | **Qualité code** | PEP 8, docstrings, type hints, structure | **/10** |
# | **TOTAL** | | **/100** |
#
# ### Critères de réussite
#
# - ✅ **Acquis (≥ 70/100)** : Système fonctionnel avec POO correcte
# - 🚧 **En cours d'acquisition (50-69/100)** : POO partielle ou bugs
# - ❌ **Non acquis (< 50/100)** : POO incorrecte ou incomplète

# %% [markdown]
# ---
#
# ## 💡 Template du diagramme UML
#
# Complétez ce diagramme Mermaid :

# %%
# %%writefile bibliotheque_uml.md
# ```mermaid
# classDiagram
#     class Livre {
#         -str isbn
#         -str titre
#         -str auteur
#         -str genre
#         -bool _disponible
#         +disponible() bool
#         +emprunter() void
#         +retourner() void
#         +__str__() str
#         +__repr__() str
#         +__eq__(other) bool
#     }
#
#     class LivreNumerique {
#         -str format
#         -float taille_mo
#         +emprunter() void
#     }
#
#     class Adherent {
#         TODO: Compléter les attributs et méthodes
#     }
#
#     class Emprunt {
#         TODO: Compléter les attributs et méthodes
#     }
#
#     class Bibliotheque {
#         TODO: Compléter les attributs et méthodes
#     }
#
#     class Observer {
#         <<abstract>>
#         +notifier(emprunt) void
#     }
#
#     class NotificationEmail {
#         +notifier(emprunt) void
#     }
#
#     class NotificationSMS {
#         +notifier(emprunt) void
#     }
#
#     %% Relations
#     LivreNumerique --|> Livre : hérite
#     NotificationEmail --|> Observer : implémente
#     NotificationSMS --|> Observer : implémente
#
#     %% TODO: Ajouter les autres relations
#     %% Bibliotheque "1" *-- "*" Livre : contient
#     %% Bibliotheque "1" *-- "*" Adherent : gère
#     %% ...
# ```

# %% [markdown]
# ---
#
# ## 💡 Squelette des classes
#
# Voici la structure de base. À vous de compléter !

# %%
from datetime import datetime, timedelta
from typing import List, Dict, Optional
from abc import ABC, abstractmethod

# ========== Exceptions ==========

class BibliothequeError(Exception):
    """Exception de base pour la bibliothèque."""
    pass

# TODO: Ajouter les autres exceptions


# ========== Classes principales ==========

class Livre:
    """Représente un livre dans le catalogue."""
    
    def __init__(self, isbn: str, titre: str, auteur: str, genre: str):
        """Initialise un livre.
        
        Args:
            isbn: Identifiant unique ISBN
            titre: Titre du livre
            auteur: Nom de l'auteur
            genre: Genre littéraire
        """
        self.isbn = isbn
        self.titre = titre
        self.auteur = auteur
        self.genre = genre
        self._disponible = True
    
    @property
    def disponible(self) -> bool:
        """Retourne si le livre est disponible."""
        # TODO: Implémenter
        pass
    
    def emprunter(self) -> None:
        """Marque le livre comme emprunté."""
        # TODO: Implémenter
        # Lever une exception si déjà emprunté
        pass
    
    def retourner(self) -> None:
        """Marque le livre comme disponible."""
        # TODO: Implémenter
        pass
    
    def __str__(self) -> str:
        """Représentation lisible du livre."""
        # TODO: Format: "Titre par Auteur (ISBN)"
        pass
    
    def __repr__(self) -> str:
        """Représentation technique du livre."""
        # TODO: Format: Livre(isbn='...', titre='...')
        pass
    
    def __eq__(self, other) -> bool:
        """Compare deux livres par ISBN."""
        # TODO: Implémenter
        pass


class LivreNumerique(Livre):
    """Représente un livre numérique."""
    
    def __init__(self, isbn: str, titre: str, auteur: str, genre: str,
                 format: str, taille_mo: float):
        """Initialise un livre numérique.
        
        Args:
            format: Format du fichier (PDF, EPUB, MOBI)
            taille_mo: Taille en Mo
        """
        # TODO: Appeler le constructeur parent
        # TODO: Ajouter les attributs spécifiques
        pass
    
    def emprunter(self) -> None:
        """Surcharge : un livre numérique reste toujours disponible."""
        # TODO: Ne rien faire (copie numérique illimitée)
        pass


class Adherent:
    """Représente un adhérent de la bibliothèque."""
    
    EMPRUNT_MAX = 3
    
    def __init__(self, id: str, nom: str, prenom: str, email: str):
        # TODO: Implémenter
        pass
    
    @property
    def nombre_emprunts(self) -> int:
        """Retourne le nombre d'emprunts en cours."""
        # TODO: Implémenter
        pass
    
    @property
    def peut_emprunter(self) -> bool:
        """Retourne si l'adhérent peut emprunter."""
        # TODO: Vérifier si < EMPRUNT_MAX
        pass
    
    def ajouter_emprunt(self, emprunt: 'Emprunt') -> None:
        """Ajoute un emprunt à l'adhérent."""
        # TODO: Implémenter
        pass
    
    def retourner_livre(self, emprunt: 'Emprunt') -> None:
        """Retire un emprunt de la liste."""
        # TODO: Implémenter
        pass
    
    def __str__(self) -> str:
        # TODO: Format: "Prenom Nom (email)"
        pass


class Emprunt:
    """Représente un emprunt de livre."""
    
    DUREE_JOURS = 21
    
    def __init__(self, livre: Livre, adherent: Adherent):
        # TODO: Initialiser les attributs
        # date_emprunt = datetime.now()
        # date_retour_prevue = date_emprunt + timedelta(days=21)
        # date_retour_effective = None
        pass
    
    @property
    def est_en_retard(self) -> bool:
        """Retourne True si l'emprunt est en retard."""
        # TODO: Vérifier si date_retour_prevue dépassée et pas retourné
        pass
    
    @property
    def jours_retard(self) -> int:
        """Retourne le nombre de jours de retard."""
        # TODO: Calculer la différence
        pass
    
    def cloturer(self) -> None:
        """Clôture l'emprunt (retour du livre)."""
        # TODO: Définir date_retour_effective
        pass
    
    def __str__(self) -> str:
        # TODO: Format lisible
        pass


class Bibliotheque:
    """Représente une bibliothèque."""
    
    def __init__(self, nom: str):
        self.nom = nom
        self._catalogue: Dict[str, Livre] = {}
        self._adherents: Dict[str, Adherent] = {}
        self._emprunts: List[Emprunt] = []
        self._observateurs: List['Observer'] = []
    
    def ajouter_livre(self, livre: Livre) -> None:
        """Ajoute un livre au catalogue."""
        # TODO: Implémenter
        pass
    
    def ajouter_adherent(self, adherent: Adherent) -> None:
        """Ajoute un adhérent."""
        # TODO: Implémenter
        pass
    
    def emprunter_livre(self, isbn: str, id_adherent: str) -> Emprunt:
        """Crée un emprunt.
        
        Raises:
            LivreInexistantError: Si le livre n'existe pas
            LivreIndisponibleError: Si le livre n'est pas disponible
            EmpruntMaxAtteintError: Si l'adhérent a atteint le max
        """
        # TODO: Implémenter toutes les vérifications
        pass
    
    def retourner_livre(self, isbn: str, id_adherent: str) -> None:
        """Clôture un emprunt."""
        # TODO: Trouver l'emprunt et le clôturer
        pass
    
    def rechercher_livre(self, titre: str) -> List[Livre]:
        """Recherche des livres par titre (recherche partielle)."""
        # TODO: Recherche insensible à la casse
        pass
    
    def livres_disponibles(self) -> List[Livre]:
        """Retourne la liste des livres disponibles."""
        # TODO: Filtrer sur disponible
        pass
    
    def ajouter_observateur(self, observateur: 'Observer') -> None:
        """Ajoute un observateur pour les notifications."""
        # TODO: Implémenter
        pass
    
    def verifier_retards(self) -> None:
        """Vérifie les retards et notifie les observateurs."""
        # TODO: Pour chaque emprunt en retard, notifier tous les observateurs
        pass
    
    def __len__(self) -> int:
        """Retourne le nombre de livres dans le catalogue."""
        # TODO: Implémenter
        pass
    
    def __str__(self) -> str:
        """Retourne les statistiques de la bibliothèque."""
        # TODO: Format: nom, nb livres, nb adhérents, nb emprunts en cours
        pass


# ========== Pattern Observer ==========

class Observer(ABC):
    """Interface pour le pattern Observer."""
    
    @abstractmethod
    def notifier(self, emprunt: Emprunt) -> None:
        """Notifie l'observateur d'un emprunt en retard."""
        pass


class NotificationEmail(Observer):
    """Observateur qui envoie des emails."""
    
    def notifier(self, emprunt: Emprunt) -> None:
        # TODO: Simuler l'envoi d'email
        pass


class NotificationSMS(Observer):
    """Observateur qui envoie des SMS."""
    
    def notifier(self, emprunt: Emprunt) -> None:
        # TODO: Simuler l'envoi de SMS
        pass

# %% [markdown]
# ---
#
# ## 🧪 Template des tests unitaires

# %%
# %%writefile test_bibliotheque.py
import pytest
from datetime import datetime, timedelta
# TODO: Importer vos classes


def test_livre_creation():
    """Test la création d'un livre."""
    # TODO: Créer un livre et vérifier ses attributs
    pass


def test_livre_emprunt():
    """Test l'emprunt d'un livre."""
    # TODO: Créer un livre, l'emprunter, vérifier qu'il n'est plus disponible
    pass


def test_livre_numerique_toujours_disponible():
    """Test qu'un livre numérique reste toujours disponible."""
    # TODO: Créer un livre numérique, l'emprunter, vérifier qu'il est toujours disponible
    pass


def test_adherent_limite_emprunts():
    """Test la limite de 3 emprunts par adhérent."""
    # TODO: Créer un adhérent, simuler 3 emprunts, vérifier peut_emprunter
    pass


def test_bibliotheque_emprunt_livre_indisponible():
    """Test qu'on ne peut pas emprunter un livre indisponible."""
    # TODO: Créer une bibliothèque, emprunter un livre, tenter de l'emprunter à nouveau
    # Vérifier que LivreIndisponibleError est levée
    with pytest.raises(LivreIndisponibleError):
        pass


def test_emprunt_en_retard():
    """Test la détection des retards."""
    # TODO: Créer un emprunt avec une date passée et vérifier est_en_retard
    pass


def test_observer_notification():
    """Test le pattern Observer pour les notifications."""
    # TODO: Créer une bibliothèque, ajouter un observateur, créer un emprunt en retard
    # Vérifier que verifier_retards() appelle bien notifier()
    pass


def test_recherche_livre():
    """Test la recherche de livres par titre."""
    # TODO: Ajouter plusieurs livres, rechercher par titre partiel
    pass

# %% [markdown]
# ---
#
# ## 🚀 Script de démonstration
#
# Créez un script qui démontre toutes les fonctionnalités.

# %%
def demo():
    """Démonstration du système de bibliothèque."""
    
    print("=" * 60)
    print("🏛️  SYSTÈME DE GESTION DE BIBLIOTHÈQUE")
    print("=" * 60)
    
    # 1. Créer une bibliothèque
    biblio = Bibliotheque("Bibliothèque Municipale de Paris")
    print(f"\n✅ Bibliothèque créée : {biblio.nom}")
    
    # 2. Ajouter des livres
    # TODO: Créer et ajouter des livres physiques et numériques
    
    # 3. Ajouter des adhérents
    # TODO: Créer et ajouter des adhérents
    
    # 4. Emprunts
    # TODO: Faire des emprunts
    
    # 5. Recherche
    # TODO: Rechercher des livres
    
    # 6. Gestion d'erreurs
    # TODO: Tenter d'emprunter un livre indisponible
    # TODO: Tenter d'emprunter plus de 3 livres
    
    # 7. Notifications de retard
    # TODO: Simuler un retard et notifier
    
    # 8. Statistiques
    print(f"\n📊 Statistiques : {biblio}")


if __name__ == "__main__":
    demo()

# %% [markdown]
# ---
#
# ## 💡 Indices et conseils
#
# ### Pour l'héritage
#
# ```python
# class LivreNumerique(Livre):
#     def __init__(self, ...):
#         super().__init__(isbn, titre, auteur, genre)  # Appel constructeur parent
#         self.format = format
#         # ...
# ```
#
# ### Pour les @property
#
# ```python
# @property
# def disponible(self) -> bool:
#     return self._disponible
#
# # Pas de setter = read-only
# ```
#
# ### Pour les exceptions
#
# ```python
# if not livre.disponible:
#     raise LivreIndisponibleError(f"Le livre {livre.titre} n'est pas disponible")
# ```
#
# ### Pour le pattern Observer
#
# ```python
# def verifier_retards(self):
#     for emprunt in self._emprunts:
#         if emprunt.est_en_retard:
#             for observateur in self._observateurs:
#                 observateur.notifier(emprunt)
# ```
#
# ### Pour les tests avec datetime
#
# ```python
# # Simuler un emprunt ancien
# emprunt.date_emprunt = datetime.now() - timedelta(days=30)
# emprunt.date_retour_prevue = emprunt.date_emprunt + timedelta(days=21)
# ```

# %% [markdown]
# ---
#
# ## 🧪 Lancer les tests

# %%
# Pour lancer les tests pytest
# !pytest test_bibliotheque.py -v

# %% [markdown]
# ---
#
# ## 📚 Ressources
#
# ### Documentation
# - [POO en Python (Real Python)](https://realpython.com/python3-object-oriented-programming/)
# - [@property decorator](https://docs.python.org/fr/3/library/functions.html#property)
# - [Abstract Base Classes](https://docs.python.org/fr/3/library/abc.html)
# - [Design Patterns en Python](https://refactoring.guru/design-patterns/python)
# - [pytest documentation](https://docs.pytest.org/)
#
# ### Concepts POO
# - Encapsulation : attributs privés (_attribut)
# - Héritage : réutilisation de code
# - Polymorphisme : surcharge de méthodes
# - Abstraction : classes abstraites (ABC)
# - Pattern Observer : découplage notification

# %% [markdown]
# ---
#
# ## ✅ Critères de validation finale
#
# Avant de soumettre, vérifiez que :
#
# 1. ✅ Le diagramme UML est complet et correct
# 2. ✅ Toutes les classes sont implémentées
# 3. ✅ L'héritage fonctionne (LivreNumerique → Livre)
# 4. ✅ Les @property sont utilisées correctement
# 5. ✅ Les 3 exceptions sont définies et utilisées
# 6. ✅ Les méthodes spéciales fonctionnent (__str__, __len__, etc.)
# 7. ✅ Le pattern Observer fonctionne
# 8. ✅ Les 5+ tests pytest passent
# 9. ✅ Le script de démonstration s'exécute sans erreur
# 10. ✅ Le code est documenté (docstrings) et propre (PEP 8)
#
# **Bon courage ! 🚀**
