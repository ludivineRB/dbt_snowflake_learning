# %% [markdown]
# # 📋 CHEATSHEET | Section 03 - POO Python
#
# # Cheatsheet POO Python
#
# Référence rapide pour la Programmation Orientée Objet en Python.

# %% [markdown]
# ## 1. Boilerplate Classe Basique

# %%
class NomClasse:
    """Documentation de la classe"""
    
    # Attribut de classe (partagé par toutes les instances)
    attribut_classe = "valeur"
    
    def __init__(self, param1, param2):
        """Constructeur"""
        self.param1 = param1  # Attribut d'instance
        self.param2 = param2
        self._prive = None     # Convention : "privé" (pas vraiment)
    
    def __str__(self):
        """Représentation pour utilisateurs (print)"""
        return f"NomClasse({self.param1}, {self.param2})"
    
    def __repr__(self):
        """Représentation pour développeurs (debug)"""
        return f"NomClasse(param1={self.param1!r}, param2={self.param2!r})"
    
    def methode_instance(self):
        """Méthode qui accède à self"""
        return f"{self.param1} - {self.param2}"
    
    @classmethod
    def methode_classe(cls, arg):
        """Méthode qui accède à la classe"""
        return cls(arg, "default")
    
    @staticmethod
    def methode_statique(arg):
        """Méthode qui n'accède ni à self ni à cls"""
        return f"Statique: {arg}"

# Utilisation
obj = NomClasse("val1", "val2")
print(str(obj))                           # Appelle __str__
print(repr(obj))                          # Appelle __repr__
print(obj.methode_instance())             # Méthode d'instance
print(NomClasse.methode_classe("test"))   # Méthode de classe
print(NomClasse.methode_statique("arg")) # Méthode statique

# %% [markdown]
# ## 2. Pattern @property

# %%
class Personne:
    def __init__(self, nom, age):
        self._nom = nom
        self._age = age
    
    @property
    def nom(self):
        """Getter"""
        return self._nom
    
    @nom.setter
    def nom(self, valeur):
        """Setter avec validation"""
        if not isinstance(valeur, str):
            raise TypeError("Le nom doit être une chaîne")
        if len(valeur) == 0:
            raise ValueError("Le nom ne peut pas être vide")
        self._nom = valeur
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self, valeur):
        if not isinstance(valeur, int):
            raise TypeError("L'âge doit être un entier")
        if valeur < 0 or valeur > 150:
            raise ValueError("Âge invalide")
        self._age = valeur
    
    @property
    def majeur(self):
        """Propriété calculée (read-only)"""
        return self._age >= 18

# Utilisation
p = Personne("Alice", 25)
print(p.nom)        # Getter
p.age = 30          # Setter
print(p.majeur)     # Propriété calculée

# %% [markdown]
# ## 3. Héritage

# %%
# Héritage simple
class Animal:
    def __init__(self, nom):
        self.nom = nom
    
    def parler(self):
        return "..."

class Chien(Animal):
    def __init__(self, nom, race):
        super().__init__(nom)  # Appeler le constructeur parent
        self.race = race
    
    def parler(self):  # Override
        return "Wouf!"
    
    def info(self):
        return f"{self.nom} ({self.race}) : {self.parler()}"

# Héritage multiple
class A:
    def methode(self):
        return "A"

class B:
    def methode(self):
        return "B"

class C(A, B):  # MRO : C -> A -> B
    pass

# Vérifier le MRO (Method Resolution Order)
print(C.mro())
# [<class 'C'>, <class 'A'>, <class 'B'>, <class 'object'>]

# Vérifier les relations
chien = Chien("Rex", "Labrador")
print(isinstance(chien, Chien))    # True
print(isinstance(chien, Animal))   # True (héritage)
print(issubclass(Chien, Animal))   # True

# %% [markdown]
# ## 4. Classes Abstraites (ABC)

# %%
from abc import ABC, abstractmethod

class Forme(ABC):
    """Classe abstraite"""
    
    @abstractmethod
    def aire(self):
        """Méthode abstraite (doit être implémentée)"""
        pass
    
    @abstractmethod
    def perimetre(self):
        pass
    
    def description(self):
        """Méthode concrète (optionnelle)"""
        return f"Aire: {self.aire()}, Périmètre: {self.perimetre()}"

class Rectangle(Forme):
    def __init__(self, largeur, hauteur):
        self.largeur = largeur
        self.hauteur = hauteur
    
    def aire(self):
        return self.largeur * self.hauteur
    
    def perimetre(self):
        return 2 * (self.largeur + self.hauteur)

# Erreur si méthodes abstraites non implémentées
# forme = Forme()  # TypeError !

# OK si toutes les méthodes sont implémentées
rect = Rectangle(5, 3)
print(rect.description())

# %% [markdown]
# ## 5. Dunder Methods (Méthodes Spéciales)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    # Représentation
    def __str__(self):
        return f"Point({self.x}, {self.y})"
    
    def __repr__(self):
        return f"Point(x={self.x}, y={self.y})"
    
    # Comparaison
    def __eq__(self, other):
        if not isinstance(other, Point):
            return NotImplemented
        return self.x == other.x and self.y == other.y
    
    def __lt__(self, other):
        if not isinstance(other, Point):
            return NotImplemented
        return (self.x**2 + self.y**2) < (other.x**2 + other.y**2)
    
    # Arithmétique
    def __add__(self, other):
        if not isinstance(other, Point):
            return NotImplemented
        return Point(self.x + other.x, self.y + other.y)
    
    def __sub__(self, other):
        if not isinstance(other, Point):
            return NotImplemented
        return Point(self.x - other.x, self.y - other.y)
    
    def __mul__(self, scalar):
        if not isinstance(scalar, (int, float)):
            return NotImplemented
        return Point(self.x * scalar, self.y * scalar)
    
    # Conteneur
    def __len__(self):
        return 2
    
    def __getitem__(self, index):
        if index == 0:
            return self.x
        elif index == 1:
            return self.y
        raise IndexError("Index doit être 0 ou 1")
    
    # Autres
    def __abs__(self):
        return (self.x**2 + self.y**2) ** 0.5
    
    def __bool__(self):
        return self.x != 0 or self.y != 0
    
    def __hash__(self):
        return hash((self.x, self.y))

# Utilisation
p1 = Point(3, 4)
p2 = Point(1, 2)

print(p1 + p2)      # __add__
print(p1 * 2)       # __mul__
print(p1 == p2)     # __eq__
print(abs(p1))      # __abs__
print(len(p1))      # __len__
print(p1[0])        # __getitem__
print(bool(p1))     # __bool__

# %% [markdown]
# ## 6. Table des Dunder Methods
#
# | Méthode | Usage | Exemple |
# |---------|-------|----------|
# | `__init__` | Constructeur | `obj = Class()` |
# | `__str__` | `str(obj)`, `print(obj)` | Affichage utilisateur |
# | `__repr__` | `repr(obj)`, shell | Affichage debug |
# | `__eq__` | `a == b` | Égalité |
# | `__ne__` | `a != b` | Inégalité |
# | `__lt__` | `a < b` | Inférieur |
# | `__le__` | `a <= b` | Inférieur ou égal |
# | `__gt__` | `a > b` | Supérieur |
# | `__ge__` | `a >= b` | Supérieur ou égal |
# | `__add__` | `a + b` | Addition |
# | `__sub__` | `a - b` | Soustraction |
# | `__mul__` | `a * b` | Multiplication |
# | `__truediv__` | `a / b` | Division |
# | `__len__` | `len(obj)` | Longueur |
# | `__getitem__` | `obj[key]` | Accès par index |
# | `__setitem__` | `obj[key] = val` | Modification par index |
# | `__contains__` | `item in obj` | Test d'appartenance |
# | `__iter__` | `for x in obj` | Rendre itérable |
# | `__call__` | `obj()` | Rendre callable |
# | `__bool__` | `bool(obj)`, `if obj` | Valeur booléenne |
# | `__hash__` | `hash(obj)`, dict/set | Calcul du hash |
# | `__enter__`, `__exit__` | `with obj:` | Context manager |

# %% [markdown]
# ## 7. Exception Handling

# %%
# Template complet
try:
    # Code qui peut lever une exception
    resultat = 10 / 2
except ZeroDivisionError as e:
    # Gestion d'erreur spécifique
    print(f"Division par zéro : {e}")
    resultat = None
except (TypeError, ValueError) as e:
    # Plusieurs types d'exceptions
    print(f"Erreur de type ou valeur : {e}")
    resultat = None
except Exception as e:
    # Attraper toutes les autres exceptions
    print(f"Erreur inattendue : {e}")
    resultat = None
else:
    # Exécuté si aucune exception
    print("Succès !")
finally:
    # Toujours exécuté
    print("Nettoyage")

# Lever une exception
def valider(x):
    if x < 0:
        raise ValueError(f"x doit être positif, pas {x}")
    return x

# Chaîner les exceptions
try:
    int("abc")
except ValueError as e:
    raise RuntimeError("Impossible de convertir") from e

# %% [markdown]
# ## 8. Exception Personnalisée

# %%
# Exception simple
class MonErreur(Exception):
    pass

# Exception avec attributs
class ValidationError(Exception):
    def __init__(self, champ, valeur, message):
        self.champ = champ
        self.valeur = valeur
        self.message = message
        super().__init__(f"{champ}: {message} (valeur={valeur})")

# Hiérarchie d'exceptions
class AppError(Exception):
    """Exception de base"""
    pass

class DatabaseError(AppError):
    """Erreurs base de données"""
    pass

class ConnectionError(DatabaseError):
    """Erreur de connexion"""
    pass

# Utilisation
try:
    raise ValidationError('email', 'invalid', 'Format invalide')
except ValidationError as e:
    print(f"Champ {e.champ} : {e.message}")

# %% [markdown]
# ## 9. Design Patterns - Exemples One-File
#
# ### Singleton

# %%
# Singleton avec métaclasse
class SingletonMeta(type):
    _instances = {}
    def __call__(cls, *args, **kwargs):
        if cls not in cls._instances:
            cls._instances[cls] = super().__call__(*args, **kwargs)
        return cls._instances[cls]

class Config(metaclass=SingletonMeta):
    def __init__(self):
        self.settings = {}

# Singleton avec décorateur
def singleton(cls):
    instances = {}
    def get_instance(*args, **kwargs):
        if cls not in instances:
            instances[cls] = cls(*args, **kwargs)
        return instances[cls]
    return get_instance

@singleton
class Logger:
    def __init__(self):
        self.logs = []

# Test
c1 = Config()
c2 = Config()
print(f"c1 is c2 : {c1 is c2}")  # True

# %% [markdown]
# ### Factory

# %%
# Factory avec dictionnaire
class DocumentPDF:
    def ouvrir(self):
        return "PDF ouvert"

class DocumentWord:
    def ouvrir(self):
        return "Word ouvert"

class DocumentFactory:
    _types = {
        'pdf': DocumentPDF,
        'word': DocumentWord,
    }
    
    @classmethod
    def creer(cls, type_doc):
        classe = cls._types.get(type_doc)
        if classe is None:
            raise ValueError(f"Type inconnu : {type_doc}")
        return classe()

# Utilisation
doc = DocumentFactory.creer('pdf')
print(doc.ouvrir())

# %% [markdown]
# ### Strategy

# %%
# Strategy pythonique avec callables
def tri_par_prix(produit):
    return produit['prix']

def tri_par_nom(produit):
    return produit['nom']

class Trieur:
    def __init__(self, strategie):
        self.strategie = strategie
    
    def trier(self, liste):
        return sorted(liste, key=self.strategie)

# Utilisation
produits = [
    {'nom': 'B', 'prix': 30},
    {'nom': 'A', 'prix': 20},
]

trieur = Trieur(tri_par_prix)
print(trieur.trier(produits))

# %% [markdown]
# ### Observer

# %%
# Observer avec callbacks
class Sujet:
    def __init__(self):
        self._callbacks = []
        self._etat = None
    
    def abonner(self, callback):
        self._callbacks.append(callback)
    
    def notifier(self):
        for callback in self._callbacks:
            callback(self._etat)
    
    @property
    def etat(self):
        return self._etat
    
    @etat.setter
    def etat(self, valeur):
        self._etat = valeur
        self.notifier()

# Utilisation
def logger(etat):
    print(f"[LOG] État : {etat}")

sujet = Sujet()
sujet.abonner(logger)
sujet.etat = "nouveau"  # Notification automatique

# %% [markdown]
# ## 10. MRO Inspection

# %%
# Inspecter l'ordre de résolution des méthodes
class A:
    pass

class B(A):
    pass

class C(A):
    pass

class D(B, C):
    pass

# MRO : D -> B -> C -> A -> object
print("MRO de D :")
for i, classe in enumerate(D.mro()):
    print(f"  {i}. {classe}")

# Ou version courte
print(f"\nMRO court : {D.__mro__}")

# Vérifier si une classe est dans le MRO
print(f"\nA dans MRO de D : {A in D.mro()}")

# %% [markdown]
# ## 11. Introspection Quick Reference

# %%
class ExempleClasse:
    attribut_classe = "valeur"
    
    def __init__(self, x):
        self.x = x
    
    def methode(self):
        pass

obj = ExempleClasse(42)

# Type et instance
print(f"type(obj) : {type(obj)}")
print(f"isinstance(obj, ExempleClasse) : {isinstance(obj, ExempleClasse)}")

# Lister attributs et méthodes
print(f"\ndir(obj) : {dir(obj)[:5]}...")  # Premiers 5

# Dictionnaire d'attributs
print(f"\nobj.__dict__ : {obj.__dict__}")
print(f"ExempleClasse.__dict__['attribut_classe'] : {ExempleClasse.__dict__['attribut_classe']}")

# Accès dynamique
print(f"\ngetattr(obj, 'x') : {getattr(obj, 'x')}")
print(f"hasattr(obj, 'x') : {hasattr(obj, 'x')}")
print(f"hasattr(obj, 'y') : {hasattr(obj, 'y')}")

setattr(obj, 'y', 100)
print(f"Après setattr : obj.y = {obj.y}")

# Callable
print(f"\ncallable(obj.methode) : {callable(obj.methode)}")
print(f"callable(obj.x) : {callable(obj.x)}")

# Identité
print(f"\nid(obj) : {id(obj)}")
obj2 = obj
print(f"obj is obj2 : {obj is obj2}")

# %% [markdown]
# ## 12. Dataclasses (Python 3.7+)

# %%
from dataclasses import dataclass, field
from typing import List

@dataclass
class Produit:
    """Dataclass génère automatiquement __init__, __repr__, __eq__, etc."""
    nom: str
    prix: float
    stock: int = 0  # Valeur par défaut
    tags: List[str] = field(default_factory=list)  # Mutable par défaut
    
    def prix_ttc(self, tva=0.20):
        return self.prix * (1 + tva)

# Utilisation
p = Produit("Laptop", 999.99, 5, ["électronique", "ordinateur"])
print(p)  # __repr__ automatique
print(f"Prix TTC : {p.prix_ttc()}€")

# Avec frozen=True (immuable)
@dataclass(frozen=True)
class Point:
    x: int
    y: int

pt = Point(3, 4)
# pt.x = 5  # Erreur : FrozenInstanceError

# %% [markdown]
# ## 13. Context Managers

# %%
# Context manager avec classe
class Fichier:
    def __init__(self, nom):
        self.nom = nom
        self.fichier = None
    
    def __enter__(self):
        print(f"Ouverture de {self.nom}")
        self.fichier = open(self.nom, 'w')
        return self.fichier
    
    def __exit__(self, exc_type, exc_val, exc_tb):
        print(f"Fermeture de {self.nom}")
        if self.fichier:
            self.fichier.close()
        # Retourner False pour propager l'exception
        return False

# Utilisation
with Fichier('/tmp/test.txt') as f:
    f.write('Contenu')

# Context manager avec contextlib
from contextlib import contextmanager

@contextmanager
def timer(nom):
    import time
    debut = time.time()
    print(f"Début de {nom}")
    try:
        yield
    finally:
        fin = time.time()
        print(f"Fin de {nom} : {(fin-debut)*1000:.2f}ms")

# Utilisation
with timer("opération"):
    sum(range(1000000))

# %% [markdown]
# ## 14. Décorateurs de Classe

# %%
# Décorateur qui ajoute une méthode
def add_to_string(cls):
    """Ajoute une méthode to_string à la classe"""
    def to_string(self):
        return f"{cls.__name__}({', '.join(f'{k}={v}' for k, v in self.__dict__.items())})"
    cls.to_string = to_string
    return cls

@add_to_string
class User:
    def __init__(self, nom, age):
        self.nom = nom
        self.age = age

u = User("Alice", 30)
print(u.to_string())

# Décorateur avec paramètres
def singleton(cls):
    instances = {}
    def get_instance(*args, **kwargs):
        if cls not in instances:
            instances[cls] = cls(*args, **kwargs)
        return instances[cls]
    return get_instance

@singleton
class Config:
    def __init__(self):
        self.data = {}

c1 = Config()
c2 = Config()
print(f"c1 is c2 : {c1 is c2}")  # True

# %% [markdown]
# ## 15. Composition vs Héritage

# %%
# Héritage : relation "est-un" (is-a)
class Animal:
    def manger(self):
        return "Je mange"

class Chien(Animal):  # Un Chien EST-UN Animal
    def aboyer(self):
        return "Wouf!"

# Composition : relation "a-un" (has-a)
class Moteur:
    def demarrer(self):
        return "Moteur démarré"

class Voiture:  # Une Voiture A-UN Moteur
    def __init__(self):
        self.moteur = Moteur()  # Composition
    
    def demarrer(self):
        return self.moteur.demarrer()

# Préférer la composition pour la flexibilité
class Logger:
    def log(self, message):
        print(f"[LOG] {message}")

class Service:
    def __init__(self, logger):
        self.logger = logger  # Injection de dépendance
    
    def faire_quelque_chose(self):
        self.logger.log("Opération effectuée")

service = Service(Logger())
service.faire_quelque_chose()

# %% [markdown]
# ## Conseils Généraux
#
# ### Quand utiliser quoi ?
#
# - **Classe simple** : données + comportement basique
# - **@property** : validation, calculs, encapsulation
# - **Héritage** : relation "est-un" claire, peu de niveaux
# - **Composition** : flexibilité, testabilité, "a-un"
# - **ABC** : interfaces, contrats, polymorphisme
# - **Dataclass** : structures de données simples
# - **Dunder methods** : intégration avec Python (opérateurs, protocoles)
#
# ### Bonnes pratiques
#
# 1. **Toujours définir `__repr__`** (au minimum)
# 2. **Préférer composition à héritage** multiple
# 3. **SOLID principles** : Single Responsibility, etc.
# 4. **DRY** : Don't Repeat Yourself
# 5. **KISS** : Keep It Simple, Stupid
# 6. **Type hints** : améliore la lisibilité
# 7. **Docstrings** : documenter classes et méthodes
# 8. **Tests** : tester le comportement des classes
#
# ### Pièges à éviter
#
# - Attributs mutables comme valeurs par défaut
# - Héritage multiple complexe
# - Singleton avec état global
# - Over-engineering avec patterns
# - Oublier de retourner `NotImplemented` dans opérateurs
# - Confondre `__eq__` et `__hash__`
