# %% [markdown]
# # 🔴 Avancé | ⏱ 45 min | 🔑 Concepts : type, isinstance, dir, getattr, inspect
#
# # Introspection en Python
#
# ## 🎯 Objectifs
#
# - Comprendre et utiliser les outils d'introspection Python
# - Maîtriser `type()`, `isinstance()`, et `issubclass()`
# - Explorer les objets avec `dir()`, `vars()`, et `__dict__`
# - Manipuler les attributs dynamiquement avec `getattr()`, `setattr()`, `hasattr()`
# - Utiliser le module `inspect` pour l'introspection avancée
# - Comprendre les bases de la métaprogrammation
#
# ## 📚 Prérequis
#
# - Classes et objets en Python
# - Héritage et polymorphisme
# - Compréhension des attributs et méthodes

# %% [markdown]
# ## 1. Introduction à l'Introspection
#
# L'**introspection** est la capacité d'un programme à examiner ses propres objets, classes, fonctions et modules au moment de l'exécution. Python offre de riches capacités d'introspection qui permettent de :
#
# - Examiner les types et les classes
# - Lister les attributs et méthodes d'un objet
# - Accéder et modifier les attributs dynamiquement
# - Obtenir des informations sur les fonctions et classes
# - Créer des outils de débogage et de documentation automatique
#
# ### Pourquoi l'introspection ?
#
# - **Débogage** : comprendre la structure des objets
# - **Frameworks** : créer des systèmes génériques (ORM, API, etc.)
# - **Documentation automatique** : générer de la doc à partir du code
# - **Validation dynamique** : vérifier les types et structures
# - **Plugins et extensions** : charger du code dynamiquement

# %% [markdown]
# ## 2. `type()` : Obtenir le Type d'un Objet
#
# La fonction `type()` retourne le type (la classe) d'un objet.

# %%
# Types de base
print(f"type(42) : {type(42)}")
print(f"type('hello') : {type('hello')}")
print(f"type([1, 2, 3]) : {type([1, 2, 3])}")
print(f"type({{1, 2}}) : {type({1, 2})}")

# Classes personnalisées
class Personne:
    def __init__(self, nom):
        self.nom = nom

p = Personne("Alice")
print(f"\ntype(p) : {type(p)}")
print(f"type(Personne) : {type(Personne)}")

# Le type d'un type est 'type'
print(f"\ntype(type) : {type(type)}")

# Vérification de type directe (pas recommandé)
if type(p) == Personne:
    print("p est une instance de Personne")

# %% [markdown]
# ## 3. `isinstance()` et `issubclass()`
#
# ### `isinstance(objet, classe)`
#
# Vérifie si un objet est une instance d'une classe (ou d'une de ses sous-classes).
#
# **Préférez toujours `isinstance()` à `type() ==`** car elle gère l'héritage correctement.
#
# ### `issubclass(classe, parent)`
#
# Vérifie si une classe est une sous-classe d'une autre.

# %%
class Animal:
    pass

class Chien(Animal):
    pass

class Chat(Animal):
    pass

rex = Chien()
minou = Chat()

# isinstance avec héritage
print(f"isinstance(rex, Chien) : {isinstance(rex, Chien)}")
print(f"isinstance(rex, Animal) : {isinstance(rex, Animal)}")  # True grâce à l'héritage
print(f"isinstance(rex, Chat) : {isinstance(rex, Chat)}")

# Vérifier plusieurs types
print(f"\nisinstance(42, (int, float)) : {isinstance(42, (int, float))}")
print(f"isinstance('hello', (int, float)) : {isinstance('hello', (int, float))}")

# issubclass
print(f"\nissubclass(Chien, Animal) : {issubclass(Chien, Animal)}")
print(f"issubclass(Chien, Chat) : {issubclass(Chien, Chat)}")
print(f"issubclass(bool, int) : {issubclass(bool, int)}")  # Surprenant mais vrai !

# Différence entre type() et isinstance()
print(f"\ntype(rex) == Chien : {type(rex) == Chien}")
print(f"type(rex) == Animal : {type(rex) == Animal}")  # False !
print(f"isinstance(rex, Animal) : {isinstance(rex, Animal)}")  # True !

# %% [markdown]
# ## 4. `dir()` : Lister les Attributs et Méthodes
#
# La fonction `dir()` retourne une liste de tous les attributs et méthodes d'un objet.

# %%
class Voiture:
    modele = "Generique"
    
    def __init__(self, marque, annee):
        self.marque = marque
        self.annee = annee
    
    def demarrer(self):
        return f"{self.marque} démarre"
    
    def _methode_privee(self):
        pass

v = Voiture("Tesla", 2024)

# Tous les attributs (y compris les méthodes spéciales)
print("Tous les attributs :")
print(dir(v))

# Filtrer les méthodes publiques
print("\nMéthodes publiques :")
publiques = [attr for attr in dir(v) if not attr.startswith('_')]
print(publiques)

# Filtrer les méthodes spéciales (dunder)
print("\nMéthodes spéciales :")
dunder = [attr for attr in dir(v) if attr.startswith('__') and attr.endswith('__')]
print(dunder[:10])  # Afficher les 10 premières

# Comparer avec la classe
print(f"\nNombre d'attributs de l'instance : {len(dir(v))}")
print(f"Nombre d'attributs de la classe : {len(dir(Voiture))}")

# %% [markdown]
# ## 5. `getattr()`, `setattr()`, `hasattr()`, `delattr()`
#
# Ces fonctions permettent de manipuler les attributs dynamiquement (par leur nom en string).
#
# - `getattr(obj, nom, default)` : obtenir un attribut
# - `setattr(obj, nom, valeur)` : définir un attribut
# - `hasattr(obj, nom)` : vérifier si un attribut existe
# - `delattr(obj, nom)` : supprimer un attribut

# %%
class Produit:
    def __init__(self, nom, prix):
        self.nom = nom
        self.prix = prix
    
    def afficher(self):
        return f"{self.nom} - {self.prix}€"

p = Produit("Laptop", 999)

# getattr : accès dynamique
nom_attribut = "nom"
print(f"getattr(p, 'nom') : {getattr(p, nom_attribut)}")
print(f"getattr(p, 'prix') : {getattr(p, 'prix')}")

# Avec valeur par défaut si l'attribut n'existe pas
print(f"getattr(p, 'stock', 0) : {getattr(p, 'stock', 0)}")

# hasattr : vérifier l'existence
print(f"\nhasattr(p, 'nom') : {hasattr(p, 'nom')}")
print(f"hasattr(p, 'stock') : {hasattr(p, 'stock')}")
print(f"hasattr(p, 'afficher') : {hasattr(p, 'afficher')}")

# setattr : définir dynamiquement
setattr(p, 'stock', 10)
print(f"\nAprès setattr(p, 'stock', 10) :")
print(f"p.stock : {p.stock}")

# Créer de nouveaux attributs
setattr(p, 'categorie', 'Électronique')
print(f"p.categorie : {p.categorie}")

# delattr : supprimer
delattr(p, 'categorie')
print(f"\nAprès delattr(p, 'categorie') :")
print(f"hasattr(p, 'categorie') : {hasattr(p, 'categorie')}")

# %%
# Exemple pratique : sérialisation simple
class Serializable:
    def to_dict(self):
        """Convertir l'objet en dictionnaire"""
        result = {}
        for attr in dir(self):
            # Ignorer les méthodes spéciales et les méthodes
            if not attr.startswith('_') and not callable(getattr(self, attr)):
                result[attr] = getattr(self, attr)
        return result
    
    @classmethod
    def from_dict(cls, data):
        """Créer un objet à partir d'un dictionnaire"""
        obj = cls.__new__(cls)  # Créer sans appeler __init__
        for key, value in data.items():
            setattr(obj, key, value)
        return obj

class Utilisateur(Serializable):
    def __init__(self, nom, email, age):
        self.nom = nom
        self.email = email
        self.age = age
    
    def __repr__(self):
        return f"Utilisateur({self.nom!r}, {self.email!r}, {self.age})"

# Sérialisation
u1 = Utilisateur("Alice", "alice@example.com", 30)
data = u1.to_dict()
print(f"Sérialisation : {data}")

# Désérialisation
u2 = Utilisateur.from_dict(data)
print(f"Désérialisation : {u2}")
print(f"u2.nom : {u2.nom}")

# %% [markdown]
# ## 6. `vars()` et `__dict__`
#
# - `vars(obj)` : retourne le dictionnaire `__dict__` d'un objet
# - `obj.__dict__` : dictionnaire contenant tous les attributs d'instance
#
# **Attention** : tous les objets n'ont pas de `__dict__` (notamment ceux avec `__slots__`).

# %%
class Livre:
    def __init__(self, titre, auteur, annee):
        self.titre = titre
        self.auteur = auteur
        self.annee = annee

livre = Livre("1984", "George Orwell", 1949)

# Accéder au __dict__
print(f"livre.__dict__ : {livre.__dict__}")
print(f"vars(livre) : {vars(livre)}")

# Modifier via __dict__
livre.__dict__['pages'] = 328
print(f"\nAprès modification de __dict__ :")
print(f"livre.pages : {livre.pages}")

# __dict__ de la classe (attributs de classe)
class MaClasse:
    attribut_classe = "valeur"
    
    def __init__(self):
        self.attribut_instance = "instance"

obj = MaClasse()
print(f"\nobj.__dict__ : {obj.__dict__}")  # Uniquement attributs d'instance
print(f"MaClasse.__dict__ : {dict(MaClasse.__dict__)}")  # Attributs de classe

# %%
# Exemple : classe avec __slots__ (pas de __dict__)
class PointOptimise:
    __slots__ = ('x', 'y')
    
    def __init__(self, x, y):
        self.x = x
        self.y = y

p = PointOptimise(3, 4)
print(f"p.x : {p.x}")

# Pas de __dict__
try:
    print(p.__dict__)
except AttributeError as e:
    print(f"Erreur : {e}")

# Mais on peut toujours utiliser dir() et getattr()
print(f"\nAttributs via dir() : {[a for a in dir(p) if not a.startswith('_')]}")

# %% [markdown]
# ## 7. `id()` et `is` : Identité des Objets
#
# - `id(obj)` : retourne l'identifiant unique d'un objet (adresse mémoire en CPython)
# - `is` : compare l'identité (même objet en mémoire)
# - `==` : compare la valeur (égalité)
#
# **Règle** : utilisez `is` uniquement pour `None`, `True`, `False`.

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print(f"id(a) : {id(a)}")
print(f"id(b) : {id(b)}")
print(f"id(c) : {id(c)}")

print(f"\na == b : {a == b}")  # True (même valeur)
print(f"a is b : {a is b}")    # False (objets différents)
print(f"a is c : {a is c}")    # True (même objet)

# Cas particulier : interning des petits entiers et strings
x = 42
y = 42
print(f"\nx is y : {x is y}")  # True ! (interning)

s1 = "hello"
s2 = "hello"
print(f"s1 is s2 : {s1 is s2}")  # True (interning)

# Utilisation correcte de 'is' avec None
valeur = None
if valeur is None:  # Correct
    print("\nvaleur est None")

if valeur == None:  # Fonctionne mais déconseillé
    print("Déconseillé : utiliser 'is None' à la place")

# %% [markdown]
# ## 8. Module `inspect` : Introspection Avancée
#
# Le module `inspect` offre des fonctions puissantes pour inspecter les objets Python.

# %%
import inspect

class Calculatrice:
    """Une calculatrice simple"""
    
    def additionner(self, a, b):
        """Additionne deux nombres"""
        return a + b
    
    def multiplier(self, x: int, y: int = 1) -> int:
        """Multiplie deux entiers"""
        return x * y

calc = Calculatrice()

# Vérifier le type
print(f"inspect.isclass(Calculatrice) : {inspect.isclass(Calculatrice)}")
print(f"inspect.ismethod(calc.additionner) : {inspect.ismethod(calc.additionner)}")
print(f"inspect.isfunction(Calculatrice.additionner) : {inspect.isfunction(Calculatrice.additionner)}")

# Documentation
print(f"\nDocumentation de la classe :")
print(inspect.getdoc(Calculatrice))

print(f"\nDocumentation de la méthode :")
print(inspect.getdoc(calc.multiplier))

# %%
# Signature des fonctions
sig = inspect.signature(calc.multiplier)
print(f"Signature de multiplier : {sig}")

# Paramètres détaillés
print(f"\nParamètres :")
for nom, param in sig.parameters.items():
    print(f"  {nom}:")
    print(f"    - annotation: {param.annotation}")
    print(f"    - default: {param.default}")
    print(f"    - kind: {param.kind}")

# Type de retour
print(f"\nType de retour : {sig.return_annotation}")

# %%
# Obtenir le code source
print("Code source de la méthode multiplier :")
print(inspect.getsource(calc.multiplier))

# Membres d'une classe
print("\nMembres de Calculatrice :")
membres = inspect.getmembers(Calculatrice)
for nom, valeur in membres:
    if not nom.startswith('_'):
        print(f"  {nom}: {type(valeur).__name__}")

# %%
# Inspecter la pile d'appels
def fonction_a():
    fonction_b()

def fonction_b():
    fonction_c()

def fonction_c():
    # Afficher la pile d'appels
    print("Pile d'appels :")
    for frame_info in inspect.stack():
        print(f"  {frame_info.function} dans {frame_info.filename}:{frame_info.lineno}")

fonction_a()

# %% [markdown]
# ## 9. `callable()` : Vérifier si un Objet est Appelable
#
# La fonction `callable()` vérifie si un objet peut être appelé comme une fonction.

# %%
def ma_fonction():
    pass

class MaClasse:
    def methode(self):
        pass

class Callable:
    def __call__(self):
        return "Je suis callable !"

obj = MaClasse()
call_obj = Callable()

# Tester si callable
print(f"callable(ma_fonction) : {callable(ma_fonction)}")
print(f"callable(MaClasse) : {callable(MaClasse)}")  # Les classes sont callables
print(f"callable(obj) : {callable(obj)}")
print(f"callable(obj.methode) : {callable(obj.methode)}")
print(f"callable(call_obj) : {callable(call_obj)}")  # __call__ défini
print(f"callable(42) : {callable(42)}")
print(f"callable('hello') : {callable('hello')}")

# Utilisation pratique
def executer_si_callable(func, *args):
    if callable(func):
        return func(*args)
    else:
        return f"{func} n'est pas callable"

print(f"\nexecuter_si_callable(len, [1,2,3]) : {executer_si_callable(len, [1,2,3])}")
print(f"executer_si_callable(42) : {executer_si_callable(42)}")

# %% [markdown]
# ## 10. Introduction à la Métaprogrammation
#
# La **métaprogrammation** est le code qui manipule du code. Python offre plusieurs mécanismes :
#
# - **Décorateurs** : modifier le comportement de fonctions/classes
# - **Métaclasses** : personnaliser la création de classes
# - **`__getattr__` et `__setattr__`** : intercepter l'accès aux attributs
# - **`exec()` et `eval()`** : exécuter du code dynamiquement (dangereux !)
#
# Note : les décorateurs seront vus en détail dans un autre notebook.

# %%
# Exemple : classe qui trace tous les accès aux attributs
class TracedObject:
    def __init__(self):
        self._data = {}
    
    def __getattr__(self, name):
        print(f"[TRACE] Accès à l'attribut '{name}'")
        if name in self._data:
            return self._data[name]
        raise AttributeError(f"'{type(self).__name__}' n'a pas d'attribut '{name}'")
    
    def __setattr__(self, name, value):
        if name == '_data':
            # Permettre l'initialisation de _data
            object.__setattr__(self, name, value)
        else:
            print(f"[TRACE] Définition de l'attribut '{name}' = {value}")
            self._data[name] = value
    
    def __delattr__(self, name):
        print(f"[TRACE] Suppression de l'attribut '{name}'")
        if name in self._data:
            del self._data[name]

# Test
obj = TracedObject()
obj.nom = "Alice"  # Trace la définition
obj.age = 30       # Trace la définition
print(f"\nValeur de obj.nom : {obj.nom}")  # Trace l'accès
del obj.age        # Trace la suppression

# %%
# Exemple : auto-validation des attributs
class ValidatedObject:
    """Classe de base avec validation automatique"""
    
    _validators = {}  # {attribut: fonction_validation}
    
    def __setattr__(self, name, value):
        # Vérifier s'il y a un validateur pour cet attribut
        if name in self._validators:
            validator = self._validators[name]
            if not validator(value):
                raise ValueError(f"Validation échouée pour '{name}' avec la valeur {value}")
        object.__setattr__(self, name, value)

class Personne(ValidatedObject):
    _validators = {
        'age': lambda x: isinstance(x, int) and 0 <= x <= 150,
        'nom': lambda x: isinstance(x, str) and len(x) > 0
    }
    
    def __init__(self, nom, age):
        self.nom = nom
        self.age = age
    
    def __repr__(self):
        return f"Personne({self.nom!r}, {self.age})"

# Test
p = Personne("Alice", 30)
print(f"Personne créée : {p}")

# Validation OK
p.age = 31
print(f"Âge modifié : {p.age}")

# Validation échouée
try:
    p.age = 200
except ValueError as e:
    print(f"\nErreur : {e}")

try:
    p.nom = ""
except ValueError as e:
    print(f"Erreur : {e}")

# %% [markdown]
# ## Pièges Courants
#
# ### 1. Surutilisation de `isinstance()`
#
# Ne testez pas systématiquement les types. Python favorise le **duck typing** ("si ça marche comme un canard...").

# %%
# Mauvais : trop de vérifications de type
def additionner_mauvais(a, b):
    if not isinstance(a, (int, float)):
        raise TypeError("a doit être un nombre")
    if not isinstance(b, (int, float)):
        raise TypeError("b doit être un nombre")
    return a + b

# Bon : duck typing
def additionner_bon(a, b):
    """Fonctionne avec tout ce qui supporte +"""
    return a + b

# Fonctionne avec des types inattendus
print(f"additionner_bon('Hello', ' World') : {additionner_bon('Hello', ' World')}")
print(f"additionner_bon([1, 2], [3, 4]) : {additionner_bon([1, 2], [3, 4])}")

# %% [markdown]
# ### 2. Utiliser `type() ==` au lieu de `isinstance()`
#
# `type()` ne prend pas en compte l'héritage, contrairement à `isinstance()`.

# %%
class Animal:
    pass

class Chien(Animal):
    pass

rex = Chien()

# Mauvais : ne prend pas en compte l'héritage
print(f"type(rex) == Animal : {type(rex) == Animal}")  # False

# Bon : prend en compte l'héritage
print(f"isinstance(rex, Animal) : {isinstance(rex, Animal)}")  # True

# %% [markdown]
# ### 3. Modifier `__dict__` Directement
#
# Modifier `__dict__` directement peut contourner les validations et causer des bugs subtils.

# %%
class Compteur:
    def __init__(self):
        self._valeur = 0
    
    @property
    def valeur(self):
        return self._valeur
    
    @valeur.setter
    def valeur(self, val):
        if val < 0:
            raise ValueError("La valeur ne peut pas être négative")
        self._valeur = val

c = Compteur()

# Bon : utilise le setter
try:
    c.valeur = -5
except ValueError as e:
    print(f"Erreur (attendue) : {e}")

# Mauvais : contourne la validation
c.__dict__['_valeur'] = -10
print(f"\nValeur après modification directe de __dict__ : {c.valeur}")
print("La validation a été contournée !")

# %% [markdown]
# ## Mini-Exercices
#
# ### Exercice 1 : Explorateur d'Objets
#
# Créez une fonction `explorer(obj)` qui affiche des informations détaillées sur un objet :
# - Son type
# - Ses attributs publics (sans `_`)
# - Ses méthodes publiques
# - Sa documentation (si disponible)
# - Sa hiérarchie de classes (MRO)

# %%
# Votre code ici
def explorer(obj):
    pass

# Test
class TestClasse:
    """Une classe de test"""
    def __init__(self):
        self.attribut = "valeur"
    
    def methode(self):
        pass

# explorer(TestClasse())

# %% [markdown]
# ### Solution Exercice 1

# %%
import inspect

def explorer(obj):
    """Affiche des informations détaillées sur un objet"""
    print(f"{'='*60}")
    print(f"EXPLORATION DE : {obj}")
    print(f"{'='*60}")
    
    # Type
    print(f"\n1. TYPE")
    print(f"   Type : {type(obj)}")
    print(f"   Module : {type(obj).__module__}")
    
    # Documentation
    print(f"\n2. DOCUMENTATION")
    doc = inspect.getdoc(obj)
    if doc:
        print(f"   {doc}")
    else:
        print(f"   Aucune documentation disponible")
    
    # Hiérarchie de classes (MRO)
    print(f"\n3. HIÉRARCHIE (MRO)")
    if inspect.isclass(obj):
        mro = obj.__mro__
    else:
        mro = type(obj).__mro__
    
    for i, classe in enumerate(mro):
        print(f"   {i}. {classe}")
    
    # Attributs publics
    print(f"\n4. ATTRIBUTS PUBLICS")
    attributs = [attr for attr in dir(obj) 
                 if not attr.startswith('_') and not callable(getattr(obj, attr))]
    if attributs:
        for attr in attributs:
            valeur = getattr(obj, attr)
            print(f"   - {attr} : {valeur} ({type(valeur).__name__})")
    else:
        print(f"   Aucun attribut public")
    
    # Méthodes publiques
    print(f"\n5. MÉTHODES PUBLIQUES")
    methodes = [attr for attr in dir(obj) 
                if not attr.startswith('_') and callable(getattr(obj, attr))]
    if methodes:
        for methode in methodes:
            func = getattr(obj, methode)
            try:
                sig = inspect.signature(func)
                print(f"   - {methode}{sig}")
                doc_methode = inspect.getdoc(func)
                if doc_methode:
                    print(f"     {doc_methode}")
            except ValueError:
                print(f"   - {methode}()")
    else:
        print(f"   Aucune méthode publique")
    
    print(f"\n{'='*60}\n")

# Test
class Animal:
    """Classe de base pour les animaux"""
    pass

class Chien(Animal):
    """Un chien domestique"""
    
    def __init__(self, nom, age):
        self.nom = nom
        self.age = age
    
    def aboyer(self):
        """Le chien aboie"""
        return "Wouf!"
    
    def presenter(self, verbose=False):
        """Présente le chien"""
        return f"Je suis {self.nom}"

rex = Chien("Rex", 5)
explorer(rex)

# %% [markdown]
# ### Exercice 2 : Auto-Documentation
#
# Créez un décorateur `@autodoc` qui génère automatiquement une documentation pour une classe en inspectant ses méthodes et attributs.

# %%
# Votre code ici
def autodoc(cls):
    pass

# Test
# @autodoc
# class MaClasse:
#     def methode1(self, x):
#         pass
#     
#     def methode2(self, y):
#         pass

# %% [markdown]
# ### Solution Exercice 2

# %%
import inspect

def autodoc(cls):
    """Décorateur qui génère une documentation automatique"""
    
    # Obtenir toutes les méthodes publiques
    methodes = inspect.getmembers(cls, predicate=inspect.isfunction)
    methodes_publiques = [(nom, func) for nom, func in methodes if not nom.startswith('_')]
    
    # Construire la documentation
    doc_parts = []
    
    # Documentation existante
    if cls.__doc__:
        doc_parts.append(cls.__doc__.strip())
    else:
        doc_parts.append(f"Classe {cls.__name__}")
    
    doc_parts.append("\n")
    doc_parts.append("Méthodes disponibles :")
    doc_parts.append("-" * 40)
    
    # Ajouter chaque méthode
    for nom, func in methodes_publiques:
        sig = inspect.signature(func)
        doc_parts.append(f"\n{nom}{sig}")
        
        # Documentation de la méthode
        func_doc = inspect.getdoc(func)
        if func_doc:
            doc_parts.append(f"    {func_doc}")
    
    # Mettre à jour la docstring
    cls.__doc__ = "\n".join(doc_parts)
    
    # Ajouter une méthode pour afficher la doc
    def afficher_doc(self):
        print(cls.__doc__)
    
    cls.afficher_doc = afficher_doc
    
    return cls

# Test
@autodoc
class Calculatrice:
    """Une calculatrice simple"""
    
    def additionner(self, a, b):
        """Additionne deux nombres"""
        return a + b
    
    def multiplier(self, x, y):
        """Multiplie deux nombres"""
        return x * y
    
    def diviser(self, numerateur, denominateur):
        """Divise deux nombres"""
        if denominateur == 0:
            raise ValueError("Division par zéro")
        return numerateur / denominateur

# Afficher la documentation générée
calc = Calculatrice()
calc.afficher_doc()

# Ou avec help()
print("\n" + "="*60)
print("Avec help() :")
print("="*60)
help(Calculatrice)

# %% [markdown]
# ### Exercice 3 : Système de Plugins Simple
#
# Créez un système de plugins qui découvre automatiquement toutes les classes héritant d'une classe de base `Plugin` et les enregistre.

# %%
# Votre code ici
class Plugin:
    pass

class PluginManager:
    pass

# Test
# class MonPlugin(Plugin):
#     pass

# %% [markdown]
# ### Solution Exercice 3

# %%
from abc import ABC, abstractmethod

class Plugin(ABC):
    """Classe de base pour tous les plugins"""
    
    @abstractmethod
    def get_name(self):
        """Retourne le nom du plugin"""
        pass
    
    @abstractmethod
    def execute(self, *args, **kwargs):
        """Exécute le plugin"""
        pass

class PluginManager:
    """Gestionnaire de plugins avec découverte automatique"""
    
    def __init__(self):
        self.plugins = {}
    
    def decouvrir_plugins(self):
        """Découvre tous les plugins (sous-classes de Plugin)"""
        # Obtenir toutes les sous-classes de Plugin
        def get_all_subclasses(cls):
            all_subclasses = []
            for subclass in cls.__subclasses__():
                all_subclasses.append(subclass)
                all_subclasses.extend(get_all_subclasses(subclass))
            return all_subclasses
        
        # Enregistrer chaque plugin
        for plugin_class in get_all_subclasses(Plugin):
            # Ignorer les classes abstraites
            if not inspect.isabstract(plugin_class):
                try:
                    # Créer une instance
                    instance = plugin_class()
                    nom = instance.get_name()
                    self.plugins[nom] = instance
                    print(f"Plugin découvert : {nom} ({plugin_class.__name__})")
                except Exception as e:
                    print(f"Erreur lors du chargement de {plugin_class.__name__} : {e}")
    
    def lister_plugins(self):
        """Liste tous les plugins disponibles"""
        print(f"\nPlugins disponibles ({len(self.plugins)}) :")
        for nom, plugin in self.plugins.items():
            print(f"  - {nom} : {type(plugin).__name__}")
            doc = inspect.getdoc(plugin.execute)
            if doc:
                print(f"    {doc}")
    
    def executer(self, nom_plugin, *args, **kwargs):
        """Exécute un plugin par son nom"""
        if nom_plugin not in self.plugins:
            raise ValueError(f"Plugin '{nom_plugin}' introuvable")
        
        plugin = self.plugins[nom_plugin]
        return plugin.execute(*args, **kwargs)

# Définir quelques plugins
class PluginCalculatrice(Plugin):
    """Plugin de calcul mathématique"""
    
    def get_name(self):
        return "calculatrice"
    
    def execute(self, operation, a, b):
        """Effectue une opération mathématique"""
        operations = {
            'add': lambda x, y: x + y,
            'sub': lambda x, y: x - y,
            'mul': lambda x, y: x * y,
            'div': lambda x, y: x / y if y != 0 else None
        }
        if operation not in operations:
            raise ValueError(f"Opération '{operation}' inconnue")
        return operations[operation](a, b)

class PluginTexte(Plugin):
    """Plugin de manipulation de texte"""
    
    def get_name(self):
        return "texte"
    
    def execute(self, action, texte):
        """Manipule du texte"""
        actions = {
            'upper': str.upper,
            'lower': str.lower,
            'reverse': lambda s: s[::-1],
            'count': len
        }
        if action not in actions:
            raise ValueError(f"Action '{action}' inconnue")
        return actions[action](texte)

class PluginListe(Plugin):
    """Plugin de manipulation de listes"""
    
    def get_name(self):
        return "liste"
    
    def execute(self, action, liste):
        """Manipule des listes"""
        actions = {
            'sum': sum,
            'max': max,
            'min': min,
            'sort': sorted,
            'reverse': lambda l: list(reversed(l))
        }
        if action not in actions:
            raise ValueError(f"Action '{action}' inconnue")
        return actions[action](liste)

# Test du système
manager = PluginManager()
manager.decouvrir_plugins()
manager.lister_plugins()

# Utiliser les plugins
print("\nUtilisation des plugins :")
print(f"calculatrice add 5 3 : {manager.executer('calculatrice', 'add', 5, 3)}")
print(f"texte upper 'hello' : {manager.executer('texte', 'upper', 'hello')}")
print(f"liste sum [1,2,3,4,5] : {manager.executer('liste', 'sum', [1,2,3,4,5])}")

# %% [markdown]
# ## Conclusion
#
# L'introspection est un outil puissant en Python qui permet de :
#
# - Examiner et comprendre la structure des objets
# - Créer du code générique et réutilisable
# - Construire des frameworks et des systèmes de plugins
# - Générer de la documentation automatiquement
# - Déboguer et analyser le code
#
# ### Points clés à retenir
#
# 1. Préférez `isinstance()` à `type() ==` pour les vérifications de type
# 2. Utilisez `dir()` pour explorer les objets
# 3. Le module `inspect` offre des capacités d'introspection avancées
# 4. `getattr()`, `setattr()`, `hasattr()` permettent l'accès dynamique aux attributs
# 5. N'abusez pas des vérifications de type : favorisez le duck typing
# 6. L'introspection est la base de la métaprogrammation en Python
